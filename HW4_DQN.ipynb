# %% [markdown]
# #  Instruction
#
# In this notebook, we will learn how to implement DQN using Tensorflow for the [Cartpole environment in OpenAI gym](https://gymnasium.farama.org/environments/classic_control/cart_pole/). You are given a basic skeleton but you need to complete the code where appropriate to solve the cartpole problem.
#
# You are free to tweak the code at any part. Your are also free to tweak the hyper-parameters to improve the performance of the agent. At the end you have to evaluate the performance of the agent on 100 independent episodes on the environment and print out the average testing performance.
#
# Make sure that your final submission is a notebook that can be run from beginning to end, and that you print out the performance of the agent at the end of the notebook.

# %%
import os
#!{os.sys.executable} -m pip install gymnasium
#!{os.sys.executable} -m pip install Pillow
#!{os.sys.executable} -m pip install ipython
#!{os.sys.executable} -m pip install pygame

from PIL import Image
from IPython.display import display

import tensorflow as tf
from collections import deque
import numpy as np
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import gym
from tensorflow import keras
from tensorflow.keras import layers

# %%
# Parameters
gamma = 0.99  # discount 
envname = "CartPole-v1"  # environment name
env=gym.make(envname, render_mode="rgb_array")

obssize = env.observation_space.low.size
actsize = env.action_space.n

# %% [markdown]
# ## DQN (Deep Q Network)
#
# In previous HWs, we have learned to use Tensorflow to build deep learning models. In this HW, we will apply deep learning as function approximations in reinforcement learning.
#
# Reference: DQN https://arxiv.org/abs/1312.5602
#
#
# In tabular Q-learning, we maintain a table of state-action pairs $(s,a)$ and save one action value for each entry $Q(s,a),\forall (s,a)$. At each time step $t$, we are in state $s_t$, then we choose action based on $\epsilon-$greedy strategy. With prob $\epsilon$, choose action uniformly random; with prob $1-\epsilon$, choose action based on $$a_t = \arg\max_a Q(s_t,a)$$
#
# We then get the instant reward $r_t$, update the Q-table using the following rule
#
# $$Q(s_t,a_t) \leftarrow (1-\alpha)Q(s_t,a_t) + \alpha (r_t + \max_a \gamma Q(s_{t+1},a))$$
#
# where $\alpha \in (0,1)$ is learning rate. The algorithm is shown to converge in tabular cases. However, in cases where we cannot keep a table for state and action, we need function approximation. Consider using neural network with parameter $\theta$, the network takes as input state $s$ and action $a$. (*or some features of state and action*). Let $Q_\theta(s,a)$ be the output of the network, which estimates the optimal Q-value function for state $s$ and action $a$.
# $$Q_\theta(s,a) \approx Q^\ast(s,a)$$

# %%
def model_creator():
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(256, activation="relu", input_dim=obssize))
    model.add(tf.keras.layers.Dropout(0.2))
    model.add(tf.keras.layers.Dense(256, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.2))
    model.add(tf.keras.layers.Dense(256, activation='relu'))
    model.add(tf.keras.layers.Dense(actsize, activation="linear"))
    return model

# %% [markdown]
# We wish to train the neural network in order to find $\theta$ such that $Q_\theta(s,a)$ approximates $Q^*(s,a)$. As we discussed in the class, we can use observations of form $(s_i, a_i, r_i, s'_{i})$ (i.e., observing reward $r_i$ and new state $s'_{i}$ on taking action $a_i$ in state $s_i$) for training. Based on observations, we can use stochastic gradient descent to update $\theta$ in the direction that minimizes the loss function. Further, based on values $Q_\theta(s,a)$, we can choose the action based on $\epsilon$-greedy policy.

# %% [markdown]
# Formally let $d_i$ be the target for the $i$-th sample $(s_t,a_t,r_t,s_{t+1})$
#
# $$d_i =  r_t +   \gamma \max_a Q_\theta(s_{t+1},a)$$
#
# We can collect a batch of $N$ samples (this generalizes the per sample update $N=1$ discusssed in class), consider the loss fucntion,
#
# $$J:=\frac{1}{N} \sum_{i=1}^N (Q_\theta(s_i,a_i) - d_i)^2$$
#
# and update
#
# $$
# \theta \leftarrow \theta -\alpha \nabla_\theta J
# $$
#
# This procedure has been shown to be fairly unstable. In class, we discussed two techniques to stabilize the training process: target network and replay buffer.
#
# **Replay Buffer**
# Maintain a buffer $R$ to store trainsition tuples $(s_t,a_t,r_t,s_{t+1})$. When minimizing the loss, we sample batches from the replay buffer and compute gradients for update on these batches. In particular, in each update, we sample $N$ tuples $(s_t,a_t,r_t,s_{t+1})$ from buffer $R$ and then minimize the
# loss
#
# $$\frac{1}{N} \sum_{i=1}^N (Q_\theta(s_i,a_i) -  (r_i + \gamma \max_a Q_\theta(s_i^\prime,a))^2$$
#
# and update parameters.
#
# **Target Network**
# Maintain a target network in addition to the original principal network. The target network is just a copy of the original network but the parameters are not updated by gradients. The target network $\theta^{-}$ is copied from the principal network every $\tau$ time steps. Target network is used to compute the targets for update
#
# $$d_i = \max_a r_t + \gamma Q_{\theta^{-}}(s_{i}^\prime,a)$$
#
# the targets are used in the loss function to update the principal network parameters. This slowly updated target network ensures that the targets come from a relatively stationary distribution and hence stabilize learning.

# %%
batch_size = 64

# Model used for selecting actions (principal)
model = model_creator()
# Then create the target model. This will periodically be copied from the principal network 
model_target = model_creator()

model.build((batch_size,obssize,))
model_target.build((batch_size,obssize,))

# %% [markdown]
# - Complete the code below to learn an Agent using DQN.
# - You should tweak the Neural network appropriately to achieve a good reward (>100). Ideally you would want to have a reward close to 200.
# - The reference paper performs updates every 4 actions. You can experiment with this parameter to speed up the learning
# - You can experiment with other parameters as well, like learning rate, memory size, different exploration schemes (e.g., adaptive $\epsilon$ or strategic explorations with bonus rewards) and others.
#
# - As we mentioned in class, there are multiple ways to improve the efficiency even further. OPTIONALLY you can experiment with these:
#   - Prioritized Replay buffer.
#   - Double DQN
#   -Dueling DQN architecture.
#
# - In case you need to debug your code you can try printing relevant information as the training happens. For example although the performance might vary from iteration to iteration, the average Q values might increase overtime in a more smooth way. This is discussed in the refernece paper
#
# - Create a plot of the running reward sampled throughout the training at the frequency of your choice at the end of the training
# - OPTIONALLY you can create a plot for the average Q-values of the principal Q-network sampled at the frequency of your choice
#
# - Ideally you want to learn with as few episodes as possible. However you will not be graded on sample efficiency in this homework. You encouraged to try to learn efficiently though.
#
# - Note that the skeleton code includes the GradientTape construct to do the learning. Take a look [here](https://www.tensorflow.org/api_docs/python/tf/GradientTape) for an explanation of GradientTape. It allows for more flexibility than model.fit. Also it uses Adam (Adaptive Moment Estimation) for Stochastic Gradient Descent optimizer.

# %%
epsilon = 1
penalty = 10
def select_action(state, epsilonn):
    # state must be a numpy array
    if np.random.rand() < epsilonn:
        # Select a random action
        return env.action_space.sample()
    else:
        # Select the action with the highest Q-value
        q_values = model(state[None])
        return tf.argmax(q_values[0]).numpy()


optimizer = keras.optimizers.Adam(learning_rate=0.0005)

# Our Experience Replay memory 
action_history = []
state_history = []
state_next_history = []
rewards_history = []
done_history = []
episode_reward_history = []
running_reward_graph = []
episode_reward_graph = []

# Replay memory size
max_memory = 1000 # You can experiment with different sizes.

running_reward = 0
timestep_count = 0


# how often to train your model - this allows you to speed up learning
# by not performing in every iteration learning. See also refernece paper
# you can set this value to other values like 1 as well to learn every time 

update_after_actions = 4

# How often to update the target network
target_update_every = 1000
loss_function = keras.losses.Huber() # You can use the Huber loss function or the mean squared error function 
max_steps_per_episode = 1000

max_episodes = 500
last_n_reward = 100

for episode in range(max_episodes):
    state = env.reset()[0]
    episode_reward = 0
    epsilon *= 0.995

    for timestep in range(1, max_steps_per_episode):
        timestep_count += 1
        action = select_action(state, epsilon)#returns a scalar
        
        state_next, reward, done, truncated, _ = env.step(action)
        
        episode_reward += reward

        # Save action/states and other information in replay buffer
        action_history.append(action)
        state_history.append(state)
        state_next_history.append(state_next)
        rewards_history.append(reward)
        done_history.append(done)

        state = state_next

        # Update every Xth frame to speed up (optional)
        # and if you have sufficient history
        if timestep_count % update_after_actions == 0 and len(action_history) > batch_size:

            # Sample a set of batch_size memories from the history
            indices = np.random.choice(range(len(state_history)), size=batch_size, replace=False)
            state_sample = np.array([state_history[i] for i in indices])
            state_next_sample = np.array([state_next_history[i] for i in indices])
            rewards_sample = np.array([rewards_history[i] for i in indices])
            action_sample = np.array([action_history[i] for i in indices])
            done_sample = np.array([done_history[i] for i in indices])

            # Create for the sample states the targets (r+gamma * max Q(...) )
            Q_next_state = model_target.predict(state_next_sample, verbose=0)
            Q_targets = rewards_sample + gamma * np.max(Q_next_state, axis=1)

            # If the episode was ended (done_sample value is 1)
            # you can penalize the Q value of the target by some value `penalty`
            Q_targets -= penalty*done_sample



            # What actions are relevant and need updating
            relevant_actions = tf.one_hot(action_sample, actsize)
            # we will use Gradient tape to do a custom gradient 
            # in the `with` environment we will record a set of operations
            # and then we will take gradients with respect to the trainable parameters
            # in the neural network
            with tf.GradientTape() as tape:
                # Train the model on your action selecting network
                #state_sample = tf.convert_to_tensor(state_sample)
                q_values = model(state_sample, training=True) 
                # We consider only the relevant actions
                Q_of_actions = tf.reduce_sum(tf.multiply(q_values, relevant_actions), axis=1)
                # Calculate loss between principal network and target network
                loss = loss_function(Q_targets, Q_of_actions)
            
            # Nudge the weights of the trainable variables towards 
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            

        if timestep_count % target_update_every == 0:
            # update the the target network with new weights
            model_target.set_weights(model.get_weights())
            # Log details
            #template = "running reward: {:.2f} at episode {}, frame count {}, epsilon {}"
            #print(template.format(running_reward, episode_count, timestep_count, epsilon))

        # Don't let the memory grow beyond the limit
        if len(rewards_history) > max_memory:
            del rewards_history[:1]
            del state_history[:1]
            del state_next_history[:1]
            del action_history[:1]
            del done_history[:1]
        if done or truncated: break

    # reward of last 100
    #print(f"Episode {episode} reward: {episode_reward}")
    

    episode_reward_history.append(episode_reward)
    if len(episode_reward_history) > last_n_reward: del episode_reward_history[:1]
    running_reward = np.mean(episode_reward_history)
    print(f"E: {episode}/{max_episodes}: \nAvg Reward: {running_reward:.2f}, Episode Reward: {episode_reward} Epsilon: {epsilon}")
    running_reward_graph.append(running_reward)

    # If you want to stop your training once you achieve the reward you want you can
    # have an if statement here. Alternatively you can stop after a fixed number
    # of episodes.
# Out:
# E: 0/500:
# Avg Reward: 23.00, Episode Reward: 23.0 Epsilon: 0.995
# E: 1/500:
# Avg Reward: 23.00, Episode Reward: 23.0 Epsilon: 0.990025
# E: 2/500:
# Avg Reward: 21.33, Episode Reward: 18.0 Epsilon: 0.985074875
# E: 3/500:
# Avg Reward: 20.25, Episode Reward: 17.0 Epsilon: 0.9801495006250001
# E: 4/500:
# Avg Reward: 18.60, Episode Reward: 12.0 Epsilon: 0.9752487531218751
# E: 5/500:
# Avg Reward: 17.50, Episode Reward: 12.0 Epsilon: 0.9703725093562657
# E: 6/500:
# Avg Reward: 17.29, Episode Reward: 16.0 Epsilon: 0.9655206468094844
# E: 7/500:
# Avg Reward: 17.25, Episode Reward: 17.0 Epsilon: 0.960693043575437
# E: 8/500:
# Avg Reward: 17.67, Episode Reward: 21.0 Epsilon: 0.9558895783575597
# E: 9/500:
# Avg Reward: 17.80, Episode Reward: 19.0 Epsilon: 0.9511101304657719
# E: 10/500:
# Avg Reward: 17.27, Episode Reward: 12.0 Epsilon: 0.946354579813443
# E: 11/500:
# Avg Reward: 18.42, Episode Reward: 31.0 Epsilon: 0.9416228069143757
# E: 12/500:
# Avg Reward: 18.69, Episode Reward: 22.0 Epsilon: 0.9369146928798039
# E: 13/500:
# Avg Reward: 18.93, Episode Reward: 22.0 Epsilon: 0.9322301194154049
# E: 14/500:
# Avg Reward: 18.53, Episode Reward: 13.0 Epsilon: 0.9275689688183278
# E: 15/500:
# Avg Reward: 18.06, Episode Reward: 11.0 Epsilon: 0.9229311239742362
# E: 16/500:
# Avg Reward: 17.59, Episode Reward: 10.0 Epsilon: 0.918316468354365
# E: 17/500:
# Avg Reward: 17.28, Episode Reward: 12.0 Epsilon: 0.9137248860125932
# E: 18/500:
# Avg Reward: 19.32, Episode Reward: 56.0 Epsilon: 0.9091562615825302
# E: 19/500:
# Avg Reward: 19.80, Episode Reward: 29.0 Epsilon: 0.9046104802746175
# E: 20/500:
# Avg Reward: 20.52, Episode Reward: 35.0 Epsilon: 0.9000874278732445
# E: 21/500:
# Avg Reward: 20.68, Episode Reward: 24.0 Epsilon: 0.8955869907338783
# E: 22/500:
# Avg Reward: 21.57, Episode Reward: 41.0 Epsilon: 0.8911090557802088
# E: 23/500:
# Avg Reward: 21.33, Episode Reward: 16.0 Epsilon: 0.8866535105013078
# E: 24/500:
# Avg Reward: 22.40, Episode Reward: 48.0 Epsilon: 0.8822202429488013
# E: 25/500:
# Avg Reward: 21.96, Episode Reward: 11.0 Epsilon: 0.8778091417340573
# E: 26/500:
# Avg Reward: 21.85, Episode Reward: 19.0 Epsilon: 0.8734200960253871
# E: 27/500:
# Avg Reward: 22.14, Episode Reward: 30.0 Epsilon: 0.8690529955452602
# E: 28/500:
# Avg Reward: 22.28, Episode Reward: 26.0 Epsilon: 0.8647077305675338
# E: 29/500:
# Avg Reward: 22.70, Episode Reward: 35.0 Epsilon: 0.8603841919146962
# E: 30/500:
# Avg Reward: 24.48, Episode Reward: 78.0 Epsilon: 0.8560822709551227
# E: 31/500:
# Avg Reward: 24.66, Episode Reward: 30.0 Epsilon: 0.851801859600347
# E: 32/500:
# Avg Reward: 24.70, Episode Reward: 26.0 Epsilon: 0.8475428503023453
# E: 33/500:
# Avg Reward: 24.44, Episode Reward: 16.0 Epsilon: 0.8433051360508336
# E: 34/500:
# Avg Reward: 24.14, Episode Reward: 14.0 Epsilon: 0.8390886103705794
# E: 35/500:
# Avg Reward: 24.42, Episode Reward: 34.0 Epsilon: 0.8348931673187264
# E: 36/500:
# Avg Reward: 24.24, Episode Reward: 18.0 Epsilon: 0.8307187014821328
# E: 37/500:
# Avg Reward: 24.68, Episode Reward: 41.0 Epsilon: 0.8265651079747222
# E: 38/500:
# Avg Reward: 24.77, Episode Reward: 28.0 Epsilon: 0.8224322824348486
# E: 39/500:
# Avg Reward: 25.32, Episode Reward: 47.0 Epsilon: 0.8183201210226743
# E: 40/500:
# Avg Reward: 25.02, Episode Reward: 13.0 Epsilon: 0.8142285204175609
# E: 41/500:
# Avg Reward: 24.71, Episode Reward: 12.0 Epsilon: 0.810157377815473
# E: 42/500:
# Avg Reward: 24.51, Episode Reward: 16.0 Epsilon: 0.8061065909263957
# E: 43/500:
# Avg Reward: 24.32, Episode Reward: 16.0 Epsilon: 0.8020760579717637
# E: 44/500:
# Avg Reward: 24.33, Episode Reward: 25.0 Epsilon: 0.798065677681905
# E: 45/500:
# Avg Reward: 24.35, Episode Reward: 25.0 Epsilon: 0.7940753492934954
# E: 46/500:
# Avg Reward: 24.91, Episode Reward: 51.0 Epsilon: 0.7901049725470279
# E: 47/500:
# Avg Reward: 25.17, Episode Reward: 37.0 Epsilon: 0.7861544476842928
# E: 48/500:
# Avg Reward: 25.14, Episode Reward: 24.0 Epsilon: 0.7822236754458713
# E: 49/500:
# Avg Reward: 24.94, Episode Reward: 15.0 Epsilon: 0.778312557068642
# E: 50/500:
# Avg Reward: 25.20, Episode Reward: 38.0 Epsilon: 0.7744209942832988
# E: 51/500:
# Avg Reward: 25.15, Episode Reward: 23.0 Epsilon: 0.7705488893118823
# E: 52/500:
# Avg Reward: 25.64, Episode Reward: 51.0 Epsilon: 0.7666961448653229
# E: 53/500:
# Avg Reward: 25.72, Episode Reward: 30.0 Epsilon: 0.7628626641409962
# E: 54/500:
# Avg Reward: 25.60, Episode Reward: 19.0 Epsilon: 0.7590483508202912
# E: 55/500:
# Avg Reward: 25.34, Episode Reward: 11.0 Epsilon: 0.7552531090661897
# E: 56/500:
# Avg Reward: 25.19, Episode Reward: 17.0 Epsilon: 0.7514768435208588
# E: 57/500:
# Avg Reward: 25.36, Episode Reward: 35.0 Epsilon: 0.7477194593032545
# E: 58/500:
# Avg Reward: 25.19, Episode Reward: 15.0 Epsilon: 0.7439808620067382
# E: 59/500:
# Avg Reward: 25.03, Episode Reward: 16.0 Epsilon: 0.7402609576967045
# E: 60/500:
# Avg Reward: 24.82, Episode Reward: 12.0 Epsilon: 0.736559652908221
# E: 61/500:
# Avg Reward: 25.02, Episode Reward: 37.0 Epsilon: 0.7328768546436799
# E: 62/500:
# Avg Reward: 24.89, Episode Reward: 17.0 Epsilon: 0.7292124703704616
# E: 63/500:
# Avg Reward: 24.72, Episode Reward: 14.0 Epsilon: 0.7255664080186093
# E: 64/500:
# Avg Reward: 24.54, Episode Reward: 13.0 Epsilon: 0.7219385759785162
# E: 65/500:
# Avg Reward: 24.41, Episode Reward: 16.0 Epsilon: 0.7183288830986236
# E: 66/500:
# Avg Reward: 24.33, Episode Reward: 19.0 Epsilon: 0.7147372386831305
# E: 67/500:
# Avg Reward: 25.59, Episode Reward: 110.0 Epsilon: 0.7111635524897149
# E: 68/500:
# Avg Reward: 25.83, Episode Reward: 42.0 Epsilon: 0.7076077347272662
# E: 69/500:
# Avg Reward: 26.19, Episode Reward: 51.0 Epsilon: 0.7040696960536299
# E: 70/500:
# Avg Reward: 26.30, Episode Reward: 34.0 Epsilon: 0.7005493475733617
# E: 71/500:
# Avg Reward: 26.10, Episode Reward: 12.0 Epsilon: 0.697046600835495
# E: 72/500:
# Avg Reward: 25.97, Episode Reward: 17.0 Epsilon: 0.6935613678313175
# E: 73/500:
# Avg Reward: 26.38, Episode Reward: 56.0 Epsilon: 0.6900935609921609
# E: 74/500:
# Avg Reward: 27.25, Episode Reward: 92.0 Epsilon: 0.6866430931872001
# E: 75/500:
# Avg Reward: 27.13, Episode Reward: 18.0 Epsilon: 0.6832098777212641
# E: 76/500:
# Avg Reward: 27.47, Episode Reward: 53.0 Epsilon: 0.6797938283326578
# E: 77/500:
# Avg Reward: 27.28, Episode Reward: 13.0 Epsilon: 0.6763948591909945
# E: 78/500:
# Avg Reward: 27.15, Episode Reward: 17.0 Epsilon: 0.6730128848950395
# E: 79/500:
# Avg Reward: 27.16, Episode Reward: 28.0 Epsilon: 0.6696478204705644
# E: 80/500:
# Avg Reward: 27.09, Episode Reward: 21.0 Epsilon: 0.6662995813682115
# E: 81/500:
# Avg Reward: 27.00, Episode Reward: 20.0 Epsilon: 0.6629680834613705
# E: 82/500:
# Avg Reward: 26.82, Episode Reward: 12.0 Epsilon: 0.6596532430440636
# E: 83/500:
# Avg Reward: 26.83, Episode Reward: 28.0 Epsilon: 0.6563549768288433
# E: 84/500:
# Avg Reward: 26.69, Episode Reward: 15.0 Epsilon: 0.653073201944699
# E: 85/500:
# Avg Reward: 26.51, Episode Reward: 11.0 Epsilon: 0.6498078359349755
# E: 86/500:
# Avg Reward: 26.52, Episode Reward: 27.0 Epsilon: 0.6465587967553006
# E: 87/500:
# Avg Reward: 27.31, Episode Reward: 96.0 Epsilon: 0.6433260027715241
# E: 88/500:
# Avg Reward: 27.17, Episode Reward: 15.0 Epsilon: 0.6401093727576664
# E: 89/500:
# Avg Reward: 27.00, Episode Reward: 12.0 Epsilon: 0.6369088258938781
# E: 90/500:
# Avg Reward: 26.95, Episode Reward: 22.0 Epsilon: 0.6337242817644086
# E: 91/500:
# Avg Reward: 26.77, Episode Reward: 11.0 Epsilon: 0.6305556603555866
# E: 92/500:
# Avg Reward: 27.00, Episode Reward: 48.0 Epsilon: 0.6274028820538087
# E: 93/500:
# Avg Reward: 27.30, Episode Reward: 55.0 Epsilon: 0.6242658676435396
# E: 94/500:
# Avg Reward: 27.26, Episode Reward: 24.0 Epsilon: 0.6211445383053219
# E: 95/500:
# Avg Reward: 27.25, Episode Reward: 26.0 Epsilon: 0.6180388156137953
# E: 96/500:
# Avg Reward: 27.37, Episode Reward: 39.0 Epsilon: 0.6149486215357263
# E: 97/500:
# Avg Reward: 27.79, Episode Reward: 68.0 Epsilon: 0.6118738784280476
# E: 98/500:
# Avg Reward: 28.22, Episode Reward: 71.0 Epsilon: 0.6088145090359074
# E: 99/500:
# Avg Reward: 28.55, Episode Reward: 61.0 Epsilon: 0.6057704364907278
# E: 100/500:
# Avg Reward: 28.73, Episode Reward: 41.0 Epsilon: 0.6027415843082742
# E: 101/500:
# Avg Reward: 29.22, Episode Reward: 72.0 Epsilon: 0.5997278763867329
# E: 102/500:
# Avg Reward: 29.63, Episode Reward: 59.0 Epsilon: 0.5967292370047992
# E: 103/500:
# Avg Reward: 29.62, Episode Reward: 16.0 Epsilon: 0.5937455908197752
# E: 104/500:
# Avg Reward: 29.72, Episode Reward: 22.0 Epsilon: 0.5907768628656763
# E: 105/500:
# Avg Reward: 30.35, Episode Reward: 75.0 Epsilon: 0.5878229785513479
# E: 106/500:
# Avg Reward: 30.96, Episode Reward: 77.0 Epsilon: 0.5848838636585911
# E: 107/500:
# Avg Reward: 31.31, Episode Reward: 52.0 Epsilon: 0.5819594443402982
# E: 108/500:
# Avg Reward: 31.36, Episode Reward: 26.0 Epsilon: 0.5790496471185967
# E: 109/500:
# Avg Reward: 31.70, Episode Reward: 53.0 Epsilon: 0.5761543988830038
# E: 110/500:
# Avg Reward: 32.49, Episode Reward: 91.0 Epsilon: 0.5732736268885887
# E: 111/500:
# Avg Reward: 32.36, Episode Reward: 18.0 Epsilon: 0.5704072587541458
# E: 112/500:
# Avg Reward: 33.08, Episode Reward: 94.0 Epsilon: 0.567555222460375
# E: 113/500:
# Avg Reward: 33.01, Episode Reward: 15.0 Epsilon: 0.5647174463480732
# E: 114/500:
# Avg Reward: 33.23, Episode Reward: 35.0 Epsilon: 0.5618938591163328
# E: 115/500:
# Avg Reward: 33.35, Episode Reward: 23.0 Epsilon: 0.5590843898207511
# E: 116/500:
# Avg Reward: 33.41, Episode Reward: 16.0 Epsilon: 0.5562889678716474
# E: 117/500:
# Avg Reward: 33.42, Episode Reward: 13.0 Epsilon: 0.5535075230322891
# E: 118/500:
# Avg Reward: 33.60, Episode Reward: 74.0 Epsilon: 0.5507399854171277
# E: 119/500:
# Avg Reward: 33.90, Episode Reward: 59.0 Epsilon: 0.547986285490042
# E: 120/500:
# Avg Reward: 33.81, Episode Reward: 26.0 Epsilon: 0.5452463540625918
# E: 121/500:
# Avg Reward: 34.52, Episode Reward: 95.0 Epsilon: 0.5425201222922789
# E: 122/500:
# Avg Reward: 34.20, Episode Reward: 9.0 Epsilon: 0.5398075216808175
# E: 123/500:
# Avg Reward: 34.40, Episode Reward: 36.0 Epsilon: 0.5371084840724134
# E: 124/500:
# Avg Reward: 34.03, Episode Reward: 11.0 Epsilon: 0.5344229416520513
# E: 125/500:
# Avg Reward: 34.05, Episode Reward: 13.0 Epsilon: 0.531750826943791
# E: 126/500:
# Avg Reward: 34.08, Episode Reward: 22.0 Epsilon: 0.5290920728090721
# E: 127/500:
# Avg Reward: 34.34, Episode Reward: 56.0 Epsilon: 0.5264466124450268
# E: 128/500:
# Avg Reward: 34.25, Episode Reward: 17.0 Epsilon: 0.5238143793828016
# E: 129/500:
# Avg Reward: 34.15, Episode Reward: 25.0 Epsilon: 0.5211953074858876
# E: 130/500:
# Avg Reward: 34.30, Episode Reward: 93.0 Epsilon: 0.5185893309484582
# E: 131/500:
# Avg Reward: 35.20, Episode Reward: 120.0 Epsilon: 0.5159963842937159
# E: 132/500:
# Avg Reward: 36.26, Episode Reward: 132.0 Epsilon: 0.5134164023722473
# E: 133/500:
# Avg Reward: 36.50, Episode Reward: 40.0 Epsilon: 0.510849320360386
# E: 134/500:
# Avg Reward: 37.28, Episode Reward: 92.0 Epsilon: 0.5082950737585841
# E: 135/500:
# Avg Reward: 37.14, Episode Reward: 20.0 Epsilon: 0.5057535983897912
# E: 136/500:
# Avg Reward: 38.40, Episode Reward: 144.0 Epsilon: 0.5032248303978422
# E: 137/500:
# Avg Reward: 38.16, Episode Reward: 17.0 Epsilon: 0.500708706245853
# E: 138/500:
# Avg Reward: 39.41, Episode Reward: 153.0 Epsilon: 0.4982051627146237
# E: 139/500:
# Avg Reward: 40.13, Episode Reward: 119.0 Epsilon: 0.49571413690105054
# E: 140/500:
# Avg Reward: 40.95, Episode Reward: 95.0 Epsilon: 0.4932355662165453
# E: 141/500:
# Avg Reward: 41.07, Episode Reward: 24.0 Epsilon: 0.4907693883854626
# E: 142/500:
# Avg Reward: 41.72, Episode Reward: 81.0 Epsilon: 0.4883155414435353
# E: 143/500:
# Avg Reward: 42.28, Episode Reward: 72.0 Epsilon: 0.4858739637363176
# E: 144/500:
# Avg Reward: 43.08, Episode Reward: 105.0 Epsilon: 0.483444593917636
# E: 145/500:
# Avg Reward: 43.24, Episode Reward: 41.0 Epsilon: 0.4810273709480478
# E: 146/500:
# Avg Reward: 42.86, Episode Reward: 13.0 Epsilon: 0.47862223409330756
# E: 147/500:
# Avg Reward: 42.88, Episode Reward: 39.0 Epsilon: 0.47622912292284103
# E: 148/500:
# Avg Reward: 43.90, Episode Reward: 126.0 Epsilon: 0.4738479773082268
# E: 149/500:
# Avg Reward: 44.76, Episode Reward: 101.0 Epsilon: 0.47147873742168567
# E: 150/500:
# Avg Reward: 44.66, Episode Reward: 28.0 Epsilon: 0.46912134373457726
# E: 151/500:
# Avg Reward: 45.46, Episode Reward: 103.0 Epsilon: 0.46677573701590436
# E: 152/500:
# Avg Reward: 45.12, Episode Reward: 17.0 Epsilon: 0.46444185833082485
# E: 153/500:
# Avg Reward: 45.02, Episode Reward: 20.0 Epsilon: 0.46211964903917074
# E: 154/500:
# Avg Reward: 45.16, Episode Reward: 33.0 Epsilon: 0.4598090507939749
# E: 155/500:
# Avg Reward: 45.20, Episode Reward: 15.0 Epsilon: 0.457510005540005
# E: 156/500:
# Avg Reward: 45.38, Episode Reward: 35.0 Epsilon: 0.45522245551230495
# E: 157/500:
# Avg Reward: 45.15, Episode Reward: 12.0 Epsilon: 0.4529463432347434
# E: 158/500:
# Avg Reward: 45.62, Episode Reward: 62.0 Epsilon: 0.4506816115185697
# E: 159/500:
# Avg Reward: 45.62, Episode Reward: 16.0 Epsilon: 0.4484282034609769
# E: 160/500:
# Avg Reward: 46.88, Episode Reward: 138.0 Epsilon: 0.446186062443672
# E: 161/500:
# Avg Reward: 48.19, Episode Reward: 168.0 Epsilon: 0.4439551321314536
# E: 162/500:
# Avg Reward: 48.19, Episode Reward: 17.0 Epsilon: 0.4417353564707963
# E: 163/500:
# Avg Reward: 48.38, Episode Reward: 33.0 Epsilon: 0.43952667968844233
# E: 164/500:
# Avg Reward: 49.78, Episode Reward: 153.0 Epsilon: 0.43732904629000013
# E: 165/500:
# Avg Reward: 50.62, Episode Reward: 100.0 Epsilon: 0.4351424010585501
# E: 166/500:
# Avg Reward: 50.95, Episode Reward: 52.0 Epsilon: 0.43296668905325736
# E: 167/500:
# Avg Reward: 50.92, Episode Reward: 107.0 Epsilon: 0.43080185560799106
# E: 168/500:
# Avg Reward: 52.29, Episode Reward: 179.0 Epsilon: 0.4286478463299511
# E: 169/500:
# Avg Reward: 51.98, Episode Reward: 20.0 Epsilon: 0.42650460709830135
# E: 170/500:
# Avg Reward: 51.76, Episode Reward: 12.0 Epsilon: 0.42437208406280985
# E: 171/500:
# Avg Reward: 51.97, Episode Reward: 33.0 Epsilon: 0.4222502236424958
# E: 172/500:
# Avg Reward: 52.83, Episode Reward: 103.0 Epsilon: 0.42013897252428334
# E: 173/500:
# Avg Reward: 52.60, Episode Reward: 33.0 Epsilon: 0.4180382776616619
# E: 174/500:
# Avg Reward: 52.57, Episode Reward: 89.0 Epsilon: 0.4159480862733536
# E: 175/500:
# Avg Reward: 53.64, Episode Reward: 125.0 Epsilon: 0.41386834584198684
# E: 176/500:
# Avg Reward: 53.27, Episode Reward: 16.0 Epsilon: 0.4117990041127769
# E: 177/500:
# Avg Reward: 53.74, Episode Reward: 60.0 Epsilon: 0.40974000909221303
# E: 178/500:
# Avg Reward: 53.74, Episode Reward: 17.0 Epsilon: 0.40769130904675194
# E: 179/500:
# Avg Reward: 53.58, Episode Reward: 12.0 Epsilon: 0.40565285250151817
# E: 180/500:
# Avg Reward: 53.89, Episode Reward: 52.0 Epsilon: 0.4036245882390106
# E: 181/500:
# Avg Reward: 54.42, Episode Reward: 73.0 Epsilon: 0.4016064652978155
# E: 182/500:
# Avg Reward: 54.67, Episode Reward: 37.0 Epsilon: 0.3995984329713264
# E: 183/500:
# Avg Reward: 54.53, Episode Reward: 14.0 Epsilon: 0.3976004408064698
# E: 184/500:
# Avg Reward: 54.52, Episode Reward: 14.0 Epsilon: 0.39561243860243744
# E: 185/500:
# Avg Reward: 54.78, Episode Reward: 37.0 Epsilon: 0.3936343764094253
# E: 186/500:
# Avg Reward: 55.86, Episode Reward: 135.0 Epsilon: 0.39166620452737816
# E: 187/500:
# Avg Reward: 55.99, Episode Reward: 109.0 Epsilon: 0.3897078735047413
# E: 188/500:
# Avg Reward: 56.59, Episode Reward: 75.0 Epsilon: 0.3877593341372176
# E: 189/500:
# Avg Reward: 57.23, Episode Reward: 76.0 Epsilon: 0.3858205374665315
# E: 190/500:
# Avg Reward: 58.49, Episode Reward: 148.0 Epsilon: 0.38389143477919885
# E: 191/500:
# Avg Reward: 58.86, Episode Reward: 48.0 Epsilon: 0.3819719776053028
# E: 192/500:
# Avg Reward: 61.22, Episode Reward: 284.0 Epsilon: 0.3800621177172763
# E: 193/500:
# Avg Reward: 63.04, Episode Reward: 237.0 Epsilon: 0.37816180712868996
# E: 194/500:
# Avg Reward: 63.57, Episode Reward: 77.0 Epsilon: 0.37627099809304654
# E: 195/500:
# Avg Reward: 63.60, Episode Reward: 29.0 Epsilon: 0.3743896431025813
# E: 196/500:
# Avg Reward: 64.58, Episode Reward: 137.0 Epsilon: 0.37251769488706843
# E: 197/500:
# Avg Reward: 64.04, Episode Reward: 14.0 Epsilon: 0.3706551064126331
# E: 198/500:
# Avg Reward: 65.75, Episode Reward: 242.0 Epsilon: 0.36880183088056995
# E: 199/500:
# Avg Reward: 65.57, Episode Reward: 43.0 Epsilon: 0.3669578217261671
# E: 200/500:
# Avg Reward: 65.98, Episode Reward: 82.0 Epsilon: 0.36512303261753626
# E: 201/500:
# Avg Reward: 65.42, Episode Reward: 16.0 Epsilon: 0.3632974174544486
# E: 202/500:
# Avg Reward: 66.41, Episode Reward: 158.0 Epsilon: 0.3614809303671764
# E: 203/500:
# Avg Reward: 67.00, Episode Reward: 75.0 Epsilon: 0.3596735257153405
# E: 204/500:
# Avg Reward: 68.13, Episode Reward: 135.0 Epsilon: 0.3578751580867638
# E: 205/500:
# Avg Reward: 69.46, Episode Reward: 208.0 Epsilon: 0.35608578229633
# E: 206/500:
# Avg Reward: 70.31, Episode Reward: 162.0 Epsilon: 0.3543053533848483
# E: 207/500:
# Avg Reward: 70.07, Episode Reward: 28.0 Epsilon: 0.35253382661792404
# E: 208/500:
# Avg Reward: 70.16, Episode Reward: 35.0 Epsilon: 0.3507711574848344
# E: 209/500:
# Avg Reward: 70.56, Episode Reward: 93.0 Epsilon: 0.34901730169741024
# E: 210/500:
# Avg Reward: 69.79, Episode Reward: 14.0 Epsilon: 0.3472722151889232
# E: 211/500:
# Avg Reward: 69.78, Episode Reward: 17.0 Epsilon: 0.3455358541129786
# E: 212/500:
# Avg Reward: 69.07, Episode Reward: 23.0 Epsilon: 0.3438081748424137
# E: 213/500:
# Avg Reward: 69.59, Episode Reward: 67.0 Epsilon: 0.3420891339682016
# E: 214/500:
# Avg Reward: 69.63, Episode Reward: 39.0 Epsilon: 0.3403786882983606
# E: 215/500:
# Avg Reward: 69.89, Episode Reward: 49.0 Epsilon: 0.3386767948568688
# E: 216/500:
# Avg Reward: 70.90, Episode Reward: 117.0 Epsilon: 0.33698341088258443
# E: 217/500:
# Avg Reward: 71.66, Episode Reward: 89.0 Epsilon: 0.3352984938281715
# E: 218/500:
# Avg Reward: 71.25, Episode Reward: 33.0 Epsilon: 0.33362200135903064
# E: 219/500:
# Avg Reward: 70.88, Episode Reward: 22.0 Epsilon: 0.33195389135223546
# E: 220/500:
# Avg Reward: 71.08, Episode Reward: 46.0 Epsilon: 0.3302941218954743
# E: 221/500:
# Avg Reward: 71.28, Episode Reward: 115.0 Epsilon: 0.32864265128599696
# E: 222/500:
# Avg Reward: 71.95, Episode Reward: 76.0 Epsilon: 0.326999438029567
# E: 223/500:
# Avg Reward: 72.29, Episode Reward: 70.0 Epsilon: 0.3253644408394192
# E: 224/500:
# Avg Reward: 73.23, Episode Reward: 105.0 Epsilon: 0.3237376186352221
# E: 225/500:
# Avg Reward: 74.82, Episode Reward: 172.0 Epsilon: 0.322118930542046
# E: 226/500:
# Avg Reward: 75.25, Episode Reward: 65.0 Epsilon: 0.32050833588933575
# E: 227/500:
# Avg Reward: 74.87, Episode Reward: 18.0 Epsilon: 0.31890579420988907
# E: 228/500:
# Avg Reward: 76.06, Episode Reward: 136.0 Epsilon: 0.3173112652388396
# E: 229/500:
# Avg Reward: 76.03, Episode Reward: 22.0 Epsilon: 0.3157247089126454
# E: 230/500:
# Avg Reward: 75.29, Episode Reward: 19.0 Epsilon: 0.3141460853680822
# E: 231/500:
# Avg Reward: 76.14, Episode Reward: 205.0 Epsilon: 0.3125753549412418
# E: 232/500:
# Avg Reward: 74.99, Episode Reward: 17.0 Epsilon: 0.31101247816653554
# E: 233/500:
# Avg Reward: 76.98, Episode Reward: 239.0 Epsilon: 0.30945741577570285
# E: 234/500:
# Avg Reward: 76.55, Episode Reward: 49.0 Epsilon: 0.3079101286968243
# E: 235/500:
# Avg Reward: 78.86, Episode Reward: 251.0 Epsilon: 0.3063705780533402
# E: 236/500:
# Avg Reward: 77.96, Episode Reward: 54.0 Epsilon: 0.30483872516307353
# E: 237/500:
# Avg Reward: 78.69, Episode Reward: 90.0 Epsilon: 0.3033145315372582
# E: 238/500:
# Avg Reward: 77.70, Episode Reward: 54.0 Epsilon: 0.3017979588795719
# E: 239/500:
# Avg Reward: 77.37, Episode Reward: 86.0 Epsilon: 0.30028896908517405
# E: 240/500:
# Avg Reward: 78.38, Episode Reward: 196.0 Epsilon: 0.2987875242397482
# E: 241/500:
# Avg Reward: 79.49, Episode Reward: 135.0 Epsilon: 0.29729358661854943
# E: 242/500:
# Avg Reward: 78.84, Episode Reward: 16.0 Epsilon: 0.29580711868545667
# E: 243/500:
# Avg Reward: 79.26, Episode Reward: 114.0 Epsilon: 0.2943280830920294
# E: 244/500:
# Avg Reward: 78.86, Episode Reward: 65.0 Epsilon: 0.29285644267656924
# E: 245/500:
# Avg Reward: 79.77, Episode Reward: 132.0 Epsilon: 0.2913921604631864
# E: 246/500:
# Avg Reward: 80.14, Episode Reward: 50.0 Epsilon: 0.28993519966087045
# E: 247/500:
# Avg Reward: 81.30, Episode Reward: 155.0 Epsilon: 0.2884855236625661
# E: 248/500:
# Avg Reward: 80.31, Episode Reward: 27.0 Epsilon: 0.28704309604425327
# E: 249/500:
# Avg Reward: 80.28, Episode Reward: 98.0 Epsilon: 0.285607880564032
# E: 250/500:
# Avg Reward: 81.55, Episode Reward: 155.0 Epsilon: 0.28417984116121187
# E: 251/500:
# Avg Reward: 81.89, Episode Reward: 137.0 Epsilon: 0.2827589419554058
# E: 252/500:
# Avg Reward: 82.15, Episode Reward: 43.0 Epsilon: 0.28134514724562876
# E: 253/500:
# Avg Reward: 82.33, Episode Reward: 38.0 Epsilon: 0.2799384215094006
# E: 254/500:
# Avg Reward: 82.35, Episode Reward: 35.0 Epsilon: 0.27853872940185365
# E: 255/500:
# Avg Reward: 82.56, Episode Reward: 36.0 Epsilon: 0.27714603575484437
# E: 256/500:
# Avg Reward: 82.37, Episode Reward: 16.0 Epsilon: 0.2757603055760701
# E: 257/500:
# Avg Reward: 83.36, Episode Reward: 111.0 Epsilon: 0.2743815040481898
# E: 258/500:
# Avg Reward: 83.53, Episode Reward: 79.0 Epsilon: 0.2730095965279488
# E: 259/500:
# Avg Reward: 83.82, Episode Reward: 45.0 Epsilon: 0.27164454854530906
# E: 260/500:
# Avg Reward: 84.74, Episode Reward: 230.0 Epsilon: 0.2702863258025825
# E: 261/500:
# Avg Reward: 83.80, Episode Reward: 74.0 Epsilon: 0.2689348941735696
# E: 262/500:
# Avg Reward: 86.68, Episode Reward: 305.0 Epsilon: 0.26759021970270175
# E: 263/500:
# Avg Reward: 88.70, Episode Reward: 235.0 Epsilon: 0.2662522686041882
# E: 264/500:
# Avg Reward: 89.20, Episode Reward: 203.0 Epsilon: 0.2649210072611673
# E: 265/500:
# Avg Reward: 89.22, Episode Reward: 102.0 Epsilon: 0.26359640222486147
# E: 266/500:
# Avg Reward: 89.27, Episode Reward: 57.0 Epsilon: 0.26227842021373715
# E: 267/500:
# Avg Reward: 90.38, Episode Reward: 218.0 Epsilon: 0.2609670281126685
# E: 268/500:
# Avg Reward: 90.41, Episode Reward: 182.0 Epsilon: 0.25966219297210513
# E: 269/500:
# Avg Reward: 90.37, Episode Reward: 16.0 Epsilon: 0.2583638820072446
# E: 270/500:
# Avg Reward: 90.46, Episode Reward: 21.0 Epsilon: 0.2570720625972084
# E: 271/500:
# Avg Reward: 91.28, Episode Reward: 115.0 Epsilon: 0.25578670228422234
# E: 272/500:
# Avg Reward: 91.22, Episode Reward: 97.0 Epsilon: 0.25450776877280124
# E: 273/500:
# Avg Reward: 93.57, Episode Reward: 268.0 Epsilon: 0.2532352299289372
# E: 274/500:
# Avg Reward: 94.12, Episode Reward: 144.0 Epsilon: 0.2519690537792925
# E: 275/500:
# Avg Reward: 94.19, Episode Reward: 132.0 Epsilon: 0.2507092085103961
# E: 276/500:
# Avg Reward: 94.73, Episode Reward: 70.0 Epsilon: 0.2494556624678441
# E: 277/500:
# Avg Reward: 94.39, Episode Reward: 26.0 Epsilon: 0.24820838415550486
# E: 278/500:
# Avg Reward: 95.67, Episode Reward: 145.0 Epsilon: 0.24696734223472733
# E: 279/500:
# Avg Reward: 96.53, Episode Reward: 98.0 Epsilon: 0.2457325055235537
# E: 280/500:
# Avg Reward: 97.59, Episode Reward: 158.0 Epsilon: 0.24450384299593592
# E: 281/500:
# Avg Reward: 98.85, Episode Reward: 199.0 Epsilon: 0.24328132378095624
# E: 282/500:
# Avg Reward: 98.65, Episode Reward: 17.0 Epsilon: 0.24206491716205145
# E: 283/500:
# Avg Reward: 100.74, Episode Reward: 223.0 Epsilon: 0.2408545925762412
# E: 284/500:
# Avg Reward: 102.02, Episode Reward: 142.0 Epsilon: 0.23965031961336
# E: 285/500:
# Avg Reward: 102.06, Episode Reward: 41.0 Epsilon: 0.2384520680152932
# E: 286/500:
# Avg Reward: 102.82, Episode Reward: 211.0 Epsilon: 0.23725980767521673
# E: 287/500:
# Avg Reward: 102.83, Episode Reward: 110.0 Epsilon: 0.23607350863684065
# E: 288/500:
# Avg Reward: 103.22, Episode Reward: 114.0 Epsilon: 0.23489314109365644
# E: 289/500:
# Avg Reward: 102.78, Episode Reward: 32.0 Epsilon: 0.23371867538818816
# E: 290/500:
# Avg Reward: 102.78, Episode Reward: 148.0 Epsilon: 0.23255008201124722
# E: 291/500:
# Avg Reward: 103.81, Episode Reward: 151.0 Epsilon: 0.231387331601191
# E: 292/500:
# Avg Reward: 102.63, Episode Reward: 166.0 Epsilon: 0.23023039494318503
# E: 293/500:
# Avg Reward: 100.96, Episode Reward: 70.0 Epsilon: 0.2290792429684691
# E: 294/500:
# Avg Reward: 101.74, Episode Reward: 155.0 Epsilon: 0.22793384675362674
# E: 295/500:
# Avg Reward: 101.94, Episode Reward: 49.0 Epsilon: 0.22679417751985861
# E: 296/500:
# Avg Reward: 100.72, Episode Reward: 15.0 Epsilon: 0.22566020663225933
# E: 297/500:
# Avg Reward: 100.79, Episode Reward: 21.0 Epsilon: 0.22453190559909803
# E: 298/500:
# Avg Reward: 98.85, Episode Reward: 48.0 Epsilon: 0.22340924607110255
# E: 299/500:
# Avg Reward: 99.23, Episode Reward: 81.0 Epsilon: 0.22229219984074702
# E: 300/500:
# Avg Reward: 100.33, Episode Reward: 192.0 Epsilon: 0.2211807388415433
# E: 301/500:
# Avg Reward: 101.45, Episode Reward: 128.0 Epsilon: 0.22007483514733558
# E: 302/500:
# Avg Reward: 101.88, Episode Reward: 201.0 Epsilon: 0.2189744609715989
# E: 303/500:
# Avg Reward: 103.62, Episode Reward: 249.0 Epsilon: 0.2178795886667409
# E: 304/500:
# Avg Reward: 103.69, Episode Reward: 142.0 Epsilon: 0.2167901907234072
# E: 305/500:
# Avg Reward: 101.96, Episode Reward: 35.0 Epsilon: 0.21570623976979014
# E: 306/500:
# Avg Reward: 101.32, Episode Reward: 98.0 Epsilon: 0.21462770857094118
# E: 307/500:
# Avg Reward: 102.22, Episode Reward: 118.0 Epsilon: 0.21355457002808648
# E: 308/500:
# Avg Reward: 102.62, Episode Reward: 75.0 Epsilon: 0.21248679717794605
# E: 309/500:
# Avg Reward: 101.88, Episode Reward: 19.0 Epsilon: 0.21142436319205632
# E: 310/500:
# Avg Reward: 102.58, Episode Reward: 84.0 Epsilon: 0.21036724137609603
# E: 311/500:
# Avg Reward: 102.64, Episode Reward: 23.0 Epsilon: 0.20931540516921554
# E: 312/500:
# Avg Reward: 103.53, Episode Reward: 112.0 Epsilon: 0.20826882814336947
# E: 313/500:
# Avg Reward: 103.61, Episode Reward: 75.0 Epsilon: 0.20722748400265262
# E: 314/500:
# Avg Reward: 103.58, Episode Reward: 36.0 Epsilon: 0.20619134658263935
# E: 315/500:
# Avg Reward: 104.64, Episode Reward: 155.0 Epsilon: 0.20516038984972615
# E: 316/500:
# Avg Reward: 107.74, Episode Reward: 427.0 Epsilon: 0.2041345879004775
# E: 317/500:
# Avg Reward: 107.53, Episode Reward: 68.0 Epsilon: 0.2031139149609751
# E: 318/500:
# Avg Reward: 107.36, Episode Reward: 16.0 Epsilon: 0.20209834538617025
# E: 319/500:
# Avg Reward: 107.86, Episode Reward: 72.0 Epsilon: 0.2010878536592394
# E: 320/500:
# Avg Reward: 107.95, Episode Reward: 55.0 Epsilon: 0.2000824143909432
# E: 321/500:
# Avg Reward: 107.23, Episode Reward: 43.0 Epsilon: 0.19908200231898848
# E: 322/500:
# Avg Reward: 108.55, Episode Reward: 208.0 Epsilon: 0.19808659230739353
# E: 323/500:
# Avg Reward: 108.44, Episode Reward: 59.0 Epsilon: 0.19709615934585656
# E: 324/500:
# Avg Reward: 107.72, Episode Reward: 33.0 Epsilon: 0.19611067854912728
# E: 325/500:
# Avg Reward: 106.82, Episode Reward: 82.0 Epsilon: 0.19513012515638165
# E: 326/500:
# Avg Reward: 108.08, Episode Reward: 191.0 Epsilon: 0.19415447453059972
# E: 327/500:
# Avg Reward: 108.55, Episode Reward: 65.0 Epsilon: 0.19318370215794672
# E: 328/500:
# Avg Reward: 108.07, Episode Reward: 88.0 Epsilon: 0.192217783647157
# E: 329/500:
# Avg Reward: 108.03, Episode Reward: 18.0 Epsilon: 0.1912566947289212
# E: 330/500:
# Avg Reward: 108.28, Episode Reward: 44.0 Epsilon: 0.1903004112552766
# E: 331/500:
# Avg Reward: 106.53, Episode Reward: 30.0 Epsilon: 0.18934890919900021
# E: 332/500:
# Avg Reward: 106.74, Episode Reward: 38.0 Epsilon: 0.18840216465300522
# E: 333/500:
# Avg Reward: 104.73, Episode Reward: 38.0 Epsilon: 0.18746015382974018
# E: 334/500:
# Avg Reward: 104.40, Episode Reward: 16.0 Epsilon: 0.1865228530605915
# E: 335/500:
# Avg Reward: 103.45, Episode Reward: 156.0 Epsilon: 0.18559023879528855
# E: 336/500:
# Avg Reward: 104.15, Episode Reward: 124.0 Epsilon: 0.1846622876013121
# E: 337/500:
# Avg Reward: 105.39, Episode Reward: 214.0 Epsilon: 0.18373897616330553
# E: 338/500:
# Avg Reward: 107.03, Episode Reward: 218.0 Epsilon: 0.182820281282489
# E: 339/500:
# Avg Reward: 107.68, Episode Reward: 151.0 Epsilon: 0.18190617987607657
# E: 340/500:
# Avg Reward: 106.82, Episode Reward: 110.0 Epsilon: 0.18099664897669618
# E: 341/500:
# Avg Reward: 107.52, Episode Reward: 205.0 Epsilon: 0.1800916657318127
# E: 342/500:
# Avg Reward: 107.84, Episode Reward: 48.0 Epsilon: 0.17919120740315364
# E: 343/500:
# Avg Reward: 108.36, Episode Reward: 166.0 Epsilon: 0.17829525136613786
# E: 344/500:
# Avg Reward: 108.56, Episode Reward: 85.0 Epsilon: 0.17740377510930716
# E: 345/500:
# Avg Reward: 107.45, Episode Reward: 21.0 Epsilon: 0.17651675623376062
# E: 346/500:
# Avg Reward: 108.15, Episode Reward: 120.0 Epsilon: 0.1756341724525918
# E: 347/500:
# Avg Reward: 109.03, Episode Reward: 243.0 Epsilon: 0.17475600159032884
# E: 348/500:
# Avg Reward: 109.74, Episode Reward: 98.0 Epsilon: 0.17388222158237718
# E: 349/500:
# Avg Reward: 109.53, Episode Reward: 77.0 Epsilon: 0.1730128104744653
# E: 350/500:
# Avg Reward: 109.03, Episode Reward: 105.0 Epsilon: 0.17214774642209296
# E: 351/500:
# Avg Reward: 108.38, Episode Reward: 72.0 Epsilon: 0.1712870076899825
# E: 352/500:
# Avg Reward: 108.43, Episode Reward: 48.0 Epsilon: 0.17043057265153258
# E: 353/500:
# Avg Reward: 109.32, Episode Reward: 127.0 Epsilon: 0.16957841978827493
# E: 354/500:
# Avg Reward: 109.37, Episode Reward: 40.0 Epsilon: 0.16873052768933355
# E: 355/500:
# Avg Reward: 110.36, Episode Reward: 135.0 Epsilon: 0.1678868750508869
# E: 356/500:
# Avg Reward: 111.45, Episode Reward: 125.0 Epsilon: 0.16704744067563246
# E: 357/500:
# Avg Reward: 110.79, Episode Reward: 45.0 Epsilon: 0.1662122034722543
# E: 358/500:
# Avg Reward: 111.88, Episode Reward: 188.0 Epsilon: 0.16538114245489302
# E: 359/500:
# Avg Reward: 112.14, Episode Reward: 71.0 Epsilon: 0.16455423674261854
# E: 360/500:
# Avg Reward: 109.99, Episode Reward: 15.0 Epsilon: 0.16373146555890544
# E: 361/500:
# Avg Reward: 109.65, Episode Reward: 40.0 Epsilon: 0.16291280823111093
# E: 362/500:
# Avg Reward: 107.63, Episode Reward: 103.0 Epsilon: 0.16209824418995536
# E: 363/500:
# Avg Reward: 105.66, Episode Reward: 38.0 Epsilon: 0.16128775296900558
# E: 364/500:
# Avg Reward: 103.79, Episode Reward: 16.0 Epsilon: 0.16048131420416054
# E: 365/500:
# Avg Reward: 103.20, Episode Reward: 43.0 Epsilon: 0.15967890763313974
# E: 366/500:
# Avg Reward: 102.76, Episode Reward: 13.0 Epsilon: 0.15888051309497406
# E: 367/500:
# Avg Reward: 100.74, Episode Reward: 16.0 Epsilon: 0.1580861105294992
# E: 368/500:
# Avg Reward: 99.04, Episode Reward: 12.0 Epsilon: 0.1572956799768517
# E: 369/500:
# Avg Reward: 99.50, Episode Reward: 62.0 Epsilon: 0.15650920157696743
# E: 370/500:
# Avg Reward: 101.02, Episode Reward: 173.0 Epsilon: 0.1557266555690826
# E: 371/500:
# Avg Reward: 100.21, Episode Reward: 34.0 Epsilon: 0.1549480222912372
# E: 372/500:
# Avg Reward: 99.43, Episode Reward: 19.0 Epsilon: 0.15417328217978102
# E: 373/500:
# Avg Reward: 97.13, Episode Reward: 38.0 Epsilon: 0.1534024157688821
# E: 374/500:
# Avg Reward: 96.59, Episode Reward: 90.0 Epsilon: 0.1526354036900377
# E: 375/500:
# Avg Reward: 95.62, Episode Reward: 35.0 Epsilon: 0.1518722266715875
# E: 376/500:
# Avg Reward: 95.31, Episode Reward: 39.0 Epsilon: 0.15111286553822956
# E: 377/500:
# Avg Reward: 95.16, Episode Reward: 11.0 Epsilon: 0.15035730121053842
# E: 378/500:
# Avg Reward: 94.06, Episode Reward: 35.0 Epsilon: 0.14960551470448571
# E: 379/500:
# Avg Reward: 93.38, Episode Reward: 30.0 Epsilon: 0.14885748713096328
# E: 380/500:
# Avg Reward: 91.99, Episode Reward: 19.0 Epsilon: 0.14811319969530845
# E: 381/500:
# Avg Reward: 90.30, Episode Reward: 30.0 Epsilon: 0.1473726336968319
# E: 382/500:
# Avg Reward: 90.49, Episode Reward: 36.0 Epsilon: 0.14663577052834775
# E: 383/500:
# Avg Reward: 90.45, Episode Reward: 219.0 Epsilon: 0.14590259167570602
# E: 384/500:
# Avg Reward: 89.17, Episode Reward: 14.0 Epsilon: 0.1451730787173275
# E: 385/500:
# Avg Reward: 88.90, Episode Reward: 14.0 Epsilon: 0.14444721332374086
# E: 386/500:
# Avg Reward: 87.13, Episode Reward: 34.0 Epsilon: 0.14372497725712216
# E: 387/500:
# Avg Reward: 89.06, Episode Reward: 303.0 Epsilon: 0.14300635237083656
# E: 388/500:
# Avg Reward: 89.89, Episode Reward: 197.0 Epsilon: 0.14229132060898236
# E: 389/500:
# Avg Reward: 90.35, Episode Reward: 78.0 Epsilon: 0.14157986400593744
# E: 390/500:
# Avg Reward: 89.11, Episode Reward: 24.0 Epsilon: 0.14087196468590776
# E: 391/500:
# Avg Reward: 88.62, Episode Reward: 102.0 Epsilon: 0.14016760486247823
# E: 392/500:
# Avg Reward: 88.21, Episode Reward: 125.0 Epsilon: 0.13946676683816583
# E: 393/500:
# Avg Reward: 89.59, Episode Reward: 208.0 Epsilon: 0.138769433003975
# E: 394/500:
# Avg Reward: 89.74, Episode Reward: 170.0 Epsilon: 0.13807558583895513
# E: 395/500:
# Avg Reward: 90.04, Episode Reward: 79.0 Epsilon: 0.13738520790976036
# E: 396/500:
# Avg Reward: 91.21, Episode Reward: 132.0 Epsilon: 0.13669828187021155
# E: 397/500:
# Avg Reward: 93.56, Episode Reward: 256.0 Epsilon: 0.13601479046086049
# E: 398/500:
# Avg Reward: 94.37, Episode Reward: 129.0 Epsilon: 0.1353347165085562
# E: 399/500:
# Avg Reward: 95.74, Episode Reward: 218.0 Epsilon: 0.1346580429260134
# E: 400/500:
# Avg Reward: 95.86, Episode Reward: 204.0 Epsilon: 0.13398475271138335
# E: 401/500:
# Avg Reward: 95.90, Episode Reward: 132.0 Epsilon: 0.13331482894782642
# E: 402/500:
# Avg Reward: 95.11, Episode Reward: 122.0 Epsilon: 0.13264825480308728
# E: 403/500:
# Avg Reward: 92.76, Episode Reward: 14.0 Epsilon: 0.13198501352907185
# E: 404/500:
# Avg Reward: 93.20, Episode Reward: 186.0 Epsilon: 0.1313250884614265
# E: 405/500:
# Avg Reward: 94.60, Episode Reward: 175.0 Epsilon: 0.13066846301911936
# E: 406/500:
# Avg Reward: 95.82, Episode Reward: 220.0 Epsilon: 0.13001512070402377
# E: 407/500:
# Avg Reward: 96.02, Episode Reward: 138.0 Epsilon: 0.12936504510050365
# E: 408/500:
# Avg Reward: 95.48, Episode Reward: 21.0 Epsilon: 0.12871821987500112
# E: 409/500:
# Avg Reward: 96.70, Episode Reward: 141.0 Epsilon: 0.12807462877562611
# E: 410/500:
# Avg Reward: 96.88, Episode Reward: 102.0 Epsilon: 0.12743425563174798
# E: 411/500:
# Avg Reward: 97.08, Episode Reward: 43.0 Epsilon: 0.12679708435358925
# E: 412/500:
# Avg Reward: 97.08, Episode Reward: 112.0 Epsilon: 0.1261630989318213
# E: 413/500:
# Avg Reward: 97.25, Episode Reward: 92.0 Epsilon: 0.1255322834371622
# E: 414/500:
# Avg Reward: 97.11, Episode Reward: 22.0 Epsilon: 0.12490462201997637
# E: 415/500:
# Avg Reward: 97.03, Episode Reward: 147.0 Epsilon: 0.1242800989098765
# E: 416/500:
# Avg Reward: 94.43, Episode Reward: 167.0 Epsilon: 0.12365869841532712
# E: 417/500:
# Avg Reward: 95.27, Episode Reward: 152.0 Epsilon: 0.12304040492325048
# E: 418/500:
# Avg Reward: 97.05, Episode Reward: 194.0 Epsilon: 0.12242520289863423
# E: 419/500:
# Avg Reward: 98.04, Episode Reward: 171.0 Epsilon: 0.12181307688414106
# E: 420/500:
# Avg Reward: 98.50, Episode Reward: 101.0 Epsilon: 0.12120401149972035
# E: 421/500:
# Avg Reward: 102.07, Episode Reward: 400.0 Epsilon: 0.12059799144222175
# E: 422/500:
# Avg Reward: 102.23, Episode Reward: 224.0 Epsilon: 0.11999500148501063
# E: 423/500:
# Avg Reward: 103.46, Episode Reward: 182.0 Epsilon: 0.11939502647758558
# E: 424/500:
# Avg Reward: 105.55, Episode Reward: 242.0 Epsilon: 0.11879805134519765
# E: 425/500:
# Avg Reward: 106.66, Episode Reward: 193.0 Epsilon: 0.11820406108847166
# E: 426/500:
# Avg Reward: 105.78, Episode Reward: 103.0 Epsilon: 0.1176130407830293
# E: 427/500:
# Avg Reward: 106.72, Episode Reward: 159.0 Epsilon: 0.11702497557911415
# E: 428/500:
# Avg Reward: 107.25, Episode Reward: 141.0 Epsilon: 0.11643985070121858
# E: 429/500:
# Avg Reward: 108.39, Episode Reward: 132.0 Epsilon: 0.11585765144771248
# E: 430/500:
# Avg Reward: 108.17, Episode Reward: 22.0 Epsilon: 0.11527836319047392
# E: 431/500:
# Avg Reward: 107.99, Episode Reward: 12.0 Epsilon: 0.11470197137452155
# E: 432/500:
# Avg Reward: 107.80, Episode Reward: 19.0 Epsilon: 0.11412846151764894
# E: 433/500:
# Avg Reward: 109.11, Episode Reward: 169.0 Epsilon: 0.1135578192100607
# E: 434/500:
# Avg Reward: 110.06, Episode Reward: 111.0 Epsilon: 0.11299003011401039
# E: 435/500:
# Avg Reward: 109.52, Episode Reward: 102.0 Epsilon: 0.11242507996344034
# E: 436/500:
# Avg Reward: 109.19, Episode Reward: 91.0 Epsilon: 0.11186295456362313
# E: 437/500:
# Avg Reward: 108.11, Episode Reward: 106.0 Epsilon: 0.11130363979080501
# E: 438/500:
# Avg Reward: 106.10, Episode Reward: 17.0 Epsilon: 0.11074712159185099
# E: 439/500:
# Avg Reward: 104.75, Episode Reward: 16.0 Epsilon: 0.11019338598389174
# E: 440/500:
# Avg Reward: 104.06, Episode Reward: 41.0 Epsilon: 0.10964241905397228
# E: 441/500:
# Avg Reward: 103.53, Episode Reward: 152.0 Epsilon: 0.10909420695870241
# E: 442/500:
# Avg Reward: 104.49, Episode Reward: 144.0 Epsilon: 0.1085487359239089
# E: 443/500:
# Avg Reward: 104.34, Episode Reward: 151.0 Epsilon: 0.10800599224428936
# E: 444/500:
# Avg Reward: 105.38, Episode Reward: 189.0 Epsilon: 0.10746596228306791
# E: 445/500:
# Avg Reward: 106.70, Episode Reward: 153.0 Epsilon: 0.10692863247165257
# E: 446/500:
# Avg Reward: 106.53, Episode Reward: 103.0 Epsilon: 0.1063939893092943
# E: 447/500:
# Avg Reward: 105.77, Episode Reward: 167.0 Epsilon: 0.10586201936274783
# E: 448/500:
# Avg Reward: 106.04, Episode Reward: 125.0 Epsilon: 0.10533270926593409
# E: 449/500:
# Avg Reward: 106.51, Episode Reward: 124.0 Epsilon: 0.10480604571960442
# E: 450/500:
# Avg Reward: 106.84, Episode Reward: 138.0 Epsilon: 0.1042820154910064
# E: 451/500:
# Avg Reward: 107.32, Episode Reward: 120.0 Epsilon: 0.10376060541355137
# E: 452/500:
# Avg Reward: 107.86, Episode Reward: 102.0 Epsilon: 0.1032418023864836
# E: 453/500:
# Avg Reward: 108.09, Episode Reward: 150.0 Epsilon: 0.10272559337455119
# E: 454/500:
# Avg Reward: 109.69, Episode Reward: 200.0 Epsilon: 0.10221196540767843
# E: 455/500:
# Avg Reward: 109.93, Episode Reward: 159.0 Epsilon: 0.10170090558064004
# E: 456/500:
# Avg Reward: 110.05, Episode Reward: 137.0 Epsilon: 0.10119240105273684
# E: 457/500:
# Avg Reward: 109.92, Episode Reward: 32.0 Epsilon: 0.10068643904747315
# E: 458/500:
# Avg Reward: 108.20, Episode Reward: 16.0 Epsilon: 0.10018300685223579
# E: 459/500:
# Avg Reward: 107.62, Episode Reward: 13.0 Epsilon: 0.0996820918179746
# E: 460/500:
# Avg Reward: 109.09, Episode Reward: 162.0 Epsilon: 0.09918368135888474
# E: 461/500:
# Avg Reward: 109.95, Episode Reward: 126.0 Epsilon: 0.09868776295209031
# E: 462/500:
# Avg Reward: 110.23, Episode Reward: 131.0 Epsilon: 0.09819432413732986
# E: 463/500:
# Avg Reward: 111.39, Episode Reward: 154.0 Epsilon: 0.09770335251664321
# E: 464/500:
# Avg Reward: 112.55, Episode Reward: 132.0 Epsilon: 0.09721483575406
# E: 465/500:
# Avg Reward: 113.37, Episode Reward: 125.0 Epsilon: 0.09672876157528969
# E: 466/500:
# Avg Reward: 113.50, Episode Reward: 26.0 Epsilon: 0.09624511776741324
# E: 467/500:
# Avg Reward: 114.60, Episode Reward: 126.0 Epsilon: 0.09576389217857617
# E: 468/500:
# Avg Reward: 116.05, Episode Reward: 157.0 Epsilon: 0.09528507271768329
# E: 469/500:
# Avg Reward: 116.55, Episode Reward: 112.0 Epsilon: 0.09480864735409487
# E: 470/500:
# Avg Reward: 117.60, Episode Reward: 278.0 Epsilon: 0.0943346041173244
# E: 471/500:
# Avg Reward: 118.55, Episode Reward: 129.0 Epsilon: 0.09386293109673778
# E: 472/500:
# Avg Reward: 120.06, Episode Reward: 170.0 Epsilon: 0.09339361644125409
# E: 473/500:
# Avg Reward: 120.81, Episode Reward: 113.0 Epsilon: 0.09292664835904782
# E: 474/500:
# Avg Reward: 121.82, Episode Reward: 191.0 Epsilon: 0.09246201511725258
# E: 475/500:
# Avg Reward: 123.15, Episode Reward: 168.0 Epsilon: 0.09199970504166631
# E: 476/500:
# Avg Reward: 124.39, Episode Reward: 163.0 Epsilon: 0.09153970651645797
# E: 477/500:
# Avg Reward: 125.96, Episode Reward: 168.0 Epsilon: 0.09108200798387568
# E: 478/500:
# Avg Reward: 127.20, Episode Reward: 159.0 Epsilon: 0.0906265979439563
# E: 479/500:
# Avg Reward: 128.25, Episode Reward: 135.0 Epsilon: 0.09017346495423652
# E: 480/500:
# Avg Reward: 129.55, Episode Reward: 149.0 Epsilon: 0.08972259762946533
# E: 481/500:
# Avg Reward: 131.32, Episode Reward: 207.0 Epsilon: 0.089273984641318
# E: 482/500:
# Avg Reward: 131.39, Episode Reward: 43.0 Epsilon: 0.0888276147181114
# E: 483/500:
# Avg Reward: 130.20, Episode Reward: 100.0 Epsilon: 0.08838347664452084
# E: 484/500:
# Avg Reward: 130.83, Episode Reward: 77.0 Epsilon: 0.08794155926129824
# E: 485/500:
# Avg Reward: 132.72, Episode Reward: 203.0 Epsilon: 0.08750185146499175
# E: 486/500:
# Avg Reward: 133.81, Episode Reward: 143.0 Epsilon: 0.08706434220766679
# E: 487/500:
# Avg Reward: 133.72, Episode Reward: 294.0 Epsilon: 0.08662902049662846
# E: 488/500:
# Avg Reward: 133.42, Episode Reward: 167.0 Epsilon: 0.08619587539414532
# E: 489/500:
# Avg Reward: 134.14, Episode Reward: 150.0 Epsilon: 0.08576489601717459
# E: 490/500:
# Avg Reward: 134.70, Episode Reward: 80.0 Epsilon: 0.08533607153708872
# E: 491/500:
# Avg Reward: 135.51, Episode Reward: 183.0 Epsilon: 0.08490939117940327
# E: 492/500:
# Avg Reward: 135.44, Episode Reward: 118.0 Epsilon: 0.08448484422350626
# E: 493/500:
# Avg Reward: 134.50, Episode Reward: 114.0 Epsilon: 0.08406242000238873
# E: 494/500:
# Avg Reward: 134.94, Episode Reward: 214.0 Epsilon: 0.08364210790237678
# E: 495/500:
# Avg Reward: 136.19, Episode Reward: 204.0 Epsilon: 0.0832238973628649
# E: 496/500:
# Avg Reward: 137.66, Episode Reward: 279.0 Epsilon: 0.08280777787605056
# E: 497/500:
# Avg Reward: 137.79, Episode Reward: 269.0 Epsilon: 0.08239373898667031
# E: 498/500:
# Avg Reward: 138.02, Episode Reward: 152.0 Epsilon: 0.08198177029173696
# E: 499/500:
# Avg Reward: 137.37, Episode Reward: 153.0 Epsilon: 0.08157186144027828

# %%
import matplotlib.pyplot as plt


# Create a list of iteration numbers
iterations = list(range(len(running_reward_graph)))

# Create the plot
plt.plot(iterations, running_reward_graph)

# Set the title and labels
plt.title("Reward Values Over Training Iterations")
plt.xlabel("Iteration")
plt.ylabel("Reward")

# Show the plot
plt.show()

# %% [markdown]
# Evaluate the performance of the agent on 100 episodes on the environment and print out the average testing performance. Alternatively you can make sure the code above terminates with 100 episodes where there is no exploration at all (epsilon=0).

# %%
from tqdm import tqdm


def evaluate(num_episodes):
    running_reward = 0
    max_steps_per_episode = 1000
    for episode in tqdm(range(num_episodes)):
        state = env.reset()[0]
        for timestep in range(1, max_steps_per_episode):
            action = select_action(state, 0)                        #returns a scalar
            state_next, reward, done, truncated, _ = env.step(action)
            running_reward += reward

            state = state_next

            if done or truncated: break
    return running_reward/num_episodes

test = evaluate(100)
# Out:
# 100%|██████████| 100/100 [00:25<00:00,  3.97it/s]

# %%
test
# Out:
# 132.62

# %% [markdown]
# 120 (update every 4 not every 1)
# 86.23 (.998 decay)
# 98.41 (.995)
# 115.32 (added dropout)
# 31 (added new 32 layer)
# 103 (took away 32 layer and made all 256)
# 105 (update every 4)
