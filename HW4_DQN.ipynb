# %% [markdown]
# #  Instruction
#
# In this notebook, we will learn how to implement DQN using Tensorflow for the [Cartpole environment in OpenAI gym](https://gymnasium.farama.org/environments/classic_control/cart_pole/). You are given a basic skeleton but you need to complete the code where appropriate to solve the cartpole problem.
#
# You are free to tweak the code at any part. Your are also free to tweak the hyper-parameters to improve the performance of the agent. At the end you have to evaluate the performance of the agent on 100 independent episodes on the environment and print out the average testing performance.
#
# Make sure that your final submission is a notebook that can be run from beginning to end, and that you print out the performance of the agent at the end of the notebook.

# %%
import os
#!{os.sys.executable} -m pip install gymnasium
#!{os.sys.executable} -m pip install Pillow
#!{os.sys.executable} -m pip install ipython
#!{os.sys.executable} -m pip install pygame

from PIL import Image
from IPython.display import display

import tensorflow as tf
from collections import deque
import numpy as np
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import gym
from tensorflow import keras
from tensorflow.keras import layers

# %%
# Parameters
gamma = 0.99  # discount 
envname = "CartPole-v1"  # environment name
env=gym.make(envname, render_mode="rgb_array")

obssize = env.observation_space.low.size
actsize = env.action_space.n

# %% [markdown]
# ## DQN (Deep Q Network)
#
# In previous HWs, we have learned to use Tensorflow to build deep learning models. In this HW, we will apply deep learning as function approximations in reinforcement learning.
#
# Reference: DQN https://arxiv.org/abs/1312.5602
#
#
# In tabular Q-learning, we maintain a table of state-action pairs $(s,a)$ and save one action value for each entry $Q(s,a),\forall (s,a)$. At each time step $t$, we are in state $s_t$, then we choose action based on $\epsilon-$greedy strategy. With prob $\epsilon$, choose action uniformly random; with prob $1-\epsilon$, choose action based on $$a_t = \arg\max_a Q(s_t,a)$$
#
# We then get the instant reward $r_t$, update the Q-table using the following rule
#
# $$Q(s_t,a_t) \leftarrow (1-\alpha)Q(s_t,a_t) + \alpha (r_t + \max_a \gamma Q(s_{t+1},a))$$
#
# where $\alpha \in (0,1)$ is learning rate. The algorithm is shown to converge in tabular cases. However, in cases where we cannot keep a table for state and action, we need function approximation. Consider using neural network with parameter $\theta$, the network takes as input state $s$ and action $a$. (*or some features of state and action*). Let $Q_\theta(s,a)$ be the output of the network, which estimates the optimal Q-value function for state $s$ and action $a$.
# $$Q_\theta(s,a) \approx Q^\ast(s,a)$$

# %%
def model_creator():
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(256, activation="relu", input_dim=obssize))
    model.add(tf.keras.layers.Dropout(0.2))
    model.add(tf.keras.layers.Dense(256, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.2))
    model.add(tf.keras.layers.Dense(256, activation='relu'))
    model.add(tf.keras.layers.Dense(actsize, activation="linear"))
    return model

# %% [markdown]
# We wish to train the neural network in order to find $\theta$ such that $Q_\theta(s,a)$ approximates $Q^*(s,a)$. As we discussed in the class, we can use observations of form $(s_i, a_i, r_i, s'_{i})$ (i.e., observing reward $r_i$ and new state $s'_{i}$ on taking action $a_i$ in state $s_i$) for training. Based on observations, we can use stochastic gradient descent to update $\theta$ in the direction that minimizes the loss function. Further, based on values $Q_\theta(s,a)$, we can choose the action based on $\epsilon$-greedy policy.

# %% [markdown]
# Formally let $d_i$ be the target for the $i$-th sample $(s_t,a_t,r_t,s_{t+1})$
#
# $$d_i =  r_t +   \gamma \max_a Q_\theta(s_{t+1},a)$$
#
# We can collect a batch of $N$ samples (this generalizes the per sample update $N=1$ discusssed in class), consider the loss fucntion,
#
# $$J:=\frac{1}{N} \sum_{i=1}^N (Q_\theta(s_i,a_i) - d_i)^2$$
#
# and update
#
# $$
# \theta \leftarrow \theta -\alpha \nabla_\theta J
# $$
#
# This procedure has been shown to be fairly unstable. In class, we discussed two techniques to stabilize the training process: target network and replay buffer.
#
# **Replay Buffer**
# Maintain a buffer $R$ to store trainsition tuples $(s_t,a_t,r_t,s_{t+1})$. When minimizing the loss, we sample batches from the replay buffer and compute gradients for update on these batches. In particular, in each update, we sample $N$ tuples $(s_t,a_t,r_t,s_{t+1})$ from buffer $R$ and then minimize the
# loss
#
# $$\frac{1}{N} \sum_{i=1}^N (Q_\theta(s_i,a_i) -  (r_i + \gamma \max_a Q_\theta(s_i^\prime,a))^2$$
#
# and update parameters.
#
# **Target Network**
# Maintain a target network in addition to the original principal network. The target network is just a copy of the original network but the parameters are not updated by gradients. The target network $\theta^{-}$ is copied from the principal network every $\tau$ time steps. Target network is used to compute the targets for update
#
# $$d_i = \max_a r_t + \gamma Q_{\theta^{-}}(s_{i}^\prime,a)$$
#
# the targets are used in the loss function to update the principal network parameters. This slowly updated target network ensures that the targets come from a relatively stationary distribution and hence stabilize learning.

# %%
batch_size = 128

# Model used for selecting actions (principal)
model = model_creator()
# Then create the target model. This will periodically be copied from the principal network 
model_target = model_creator()

model.build((batch_size,obssize,))
model_target.build((batch_size,obssize,))

# %% [markdown]
# - Complete the code below to learn an Agent using DQN.
# - You should tweak the Neural network appropriately to achieve a good reward (>100). Ideally you would want to have a reward close to 200.
# - The reference paper performs updates every 4 actions. You can experiment with this parameter to speed up the learning
# - You can experiment with other parameters as well, like learning rate, memory size, different exploration schemes (e.g., adaptive $\epsilon$ or strategic explorations with bonus rewards) and others.
#
# - As we mentioned in class, there are multiple ways to improve the efficiency even further. OPTIONALLY you can experiment with these:
#   - Prioritized Replay buffer.
#   - Double DQN
#   -Dueling DQN architecture.
#
# - In case you need to debug your code you can try printing relevant information as the training happens. For example although the performance might vary from iteration to iteration, the average Q values might increase overtime in a more smooth way. This is discussed in the refernece paper
#
# - Create a plot of the running reward sampled throughout the training at the frequency of your choice at the end of the training
# - OPTIONALLY you can create a plot for the average Q-values of the principal Q-network sampled at the frequency of your choice
#
# - Ideally you want to learn with as few episodes as possible. However you will not be graded on sample efficiency in this homework. You encouraged to try to learn efficiently though.
#
# - Note that the skeleton code includes the GradientTape construct to do the learning. Take a look [here](https://www.tensorflow.org/api_docs/python/tf/GradientTape) for an explanation of GradientTape. It allows for more flexibility than model.fit. Also it uses Adam (Adaptive Moment Estimation) for Stochastic Gradient Descent optimizer.

# %%
epsilon = 1
penalty = 10
def select_action(state, epsilonn):
    # state must be a numpy array
    if np.random.rand() < epsilonn:
        # Select a random action
        return env.action_space.sample()
    else:
        # Select the action with the highest Q-value
        q_values = model(state[None])
        return tf.argmax(q_values[0]).numpy()


optimizer = keras.optimizers.Adam(learning_rate=0.0005)

# Our Experience Replay memory 
action_history = []
state_history = []
state_next_history = []
rewards_history = []
done_history = []
episode_reward_history = []
running_reward_graph = []
episode_reward_graph = []

# Replay memory size
max_memory = 1000 # You can experiment with different sizes.

running_reward = 0
timestep_count = 0


# how often to train your model - this allows you to speed up learning
# by not performing in every iteration learning. See also refernece paper
# you can set this value to other values like 1 as well to learn every time 

update_after_actions = 4

# How often to update the target network
target_update_every = 1000
loss_function = keras.losses.Huber() # You can use the Huber loss function or the mean squared error function 
max_steps_per_episode = 1000

max_episodes = 1000
last_n_reward = 100

for episode in range(max_episodes):
    state = env.reset()[0]
    episode_reward = 0
    epsilon *= 0.996

    for timestep in range(1, max_steps_per_episode):
        timestep_count += 1
        action = select_action(state, epsilon)#returns a scalar
        
        state_next, reward, done, truncated, _ = env.step(action)
        
        episode_reward += reward

        # Save action/states and other information in replay buffer
        action_history.append(action)
        state_history.append(state)
        state_next_history.append(state_next)
        rewards_history.append(reward)
        done_history.append(done)

        state = state_next

        # Update every Xth frame to speed up (optional)
        # and if you have sufficient history
        if timestep_count % update_after_actions == 0 and len(action_history) > batch_size:

            # Sample a set of batch_size memories from the history
            indices = np.random.choice(range(len(state_history)), size=batch_size, replace=False)
            state_sample = np.array([state_history[i] for i in indices])
            state_next_sample = np.array([state_next_history[i] for i in indices])
            rewards_sample = np.array([rewards_history[i] for i in indices])
            action_sample = np.array([action_history[i] for i in indices])
            done_sample = np.array([done_history[i] for i in indices])

            # Create for the sample states the targets (r+gamma * max Q(...) )
            Q_next_state = model_target.predict(state_next_sample, verbose=0)
            Q_targets = rewards_sample + gamma * np.max(Q_next_state, axis=1)

            # If the episode was ended (done_sample value is 1)
            # you can penalize the Q value of the target by some value `penalty`
            Q_targets -= penalty*done_sample



            # What actions are relevant and need updating
            relevant_actions = tf.one_hot(action_sample, actsize)
            # we will use Gradient tape to do a custom gradient 
            # in the `with` environment we will record a set of operations
            # and then we will take gradients with respect to the trainable parameters
            # in the neural network
            with tf.GradientTape() as tape:
                # Train the model on your action selecting network
                #state_sample = tf.convert_to_tensor(state_sample)
                q_values = model(state_sample, training=True) 
                # We consider only the relevant actions
                Q_of_actions = tf.reduce_sum(tf.multiply(q_values, relevant_actions), axis=1)
                # Calculate loss between principal network and target network
                loss = loss_function(Q_targets, Q_of_actions)
            
            # Nudge the weights of the trainable variables towards 
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            

        if timestep_count % target_update_every == 0:
            # update the the target network with new weights
            model_target.set_weights(model.get_weights())
            # Log details
            #template = "running reward: {:.2f} at episode {}, frame count {}, epsilon {}"
            #print(template.format(running_reward, episode_count, timestep_count, epsilon))

        # Don't let the memory grow beyond the limit
        if len(rewards_history) > max_memory:
            del rewards_history[:1]
            del state_history[:1]
            del state_next_history[:1]
            del action_history[:1]
            del done_history[:1]
        if done or truncated: break

    # reward of last 100
    #print(f"Episode {episode} reward: {episode_reward}")
    

    episode_reward_history.append(episode_reward)
    if len(episode_reward_history) > last_n_reward: del episode_reward_history[:1]
    running_reward = np.mean(episode_reward_history)
    print(f"E: {episode}/{max_episodes}: \nAvg Reward: {running_reward:.2f}, Episode Reward: {episode_reward} Epsilon: {epsilon}")
    running_reward_graph.append(running_reward)

    # If you want to stop your training once you achieve the reward you want you can
    # have an if statement here. Alternatively you can stop after a fixed number
    # of episodes.
# Out:
# E: 0/1000:
# Avg Reward: 59.00, Episode Reward: 59.0 Epsilon: 0.996
# E: 1/1000:
# Avg Reward: 38.00, Episode Reward: 17.0 Epsilon: 0.992016
# E: 2/1000:
# Avg Reward: 30.00, Episode Reward: 14.0 Epsilon: 0.988047936
# E: 3/1000:
# Avg Reward: 25.00, Episode Reward: 10.0 Epsilon: 0.984095744256
# E: 4/1000:
# Avg Reward: 23.40, Episode Reward: 17.0 Epsilon: 0.980159361278976
# E: 5/1000:
# Avg Reward: 23.33, Episode Reward: 23.0 Epsilon: 0.97623872383386
# E: 6/1000:
# Avg Reward: 25.86, Episode Reward: 41.0 Epsilon: 0.9723337689385245
# E: 7/1000:
# Avg Reward: 24.00, Episode Reward: 11.0 Epsilon: 0.9684444338627705
# E: 8/1000:
# Avg Reward: 22.56, Episode Reward: 11.0 Epsilon: 0.9645706561273194
# E: 9/1000:
# Avg Reward: 21.30, Episode Reward: 10.0 Epsilon: 0.9607123735028101
# E: 10/1000:
# Avg Reward: 23.73, Episode Reward: 48.0 Epsilon: 0.9568695240087989
# E: 11/1000:
# Avg Reward: 22.75, Episode Reward: 12.0 Epsilon: 0.9530420459127636
# E: 12/1000:
# Avg Reward: 21.69, Episode Reward: 9.0 Epsilon: 0.9492298777291126
# E: 13/1000:
# Avg Reward: 22.29, Episode Reward: 30.0 Epsilon: 0.9454329582181962
# E: 14/1000:
# Avg Reward: 21.80, Episode Reward: 15.0 Epsilon: 0.9416512263853234
# E: 15/1000:
# Avg Reward: 21.00, Episode Reward: 9.0 Epsilon: 0.9378846214797821
# E: 16/1000:
# Avg Reward: 20.94, Episode Reward: 20.0 Epsilon: 0.934133082993863
# E: 17/1000:
# Avg Reward: 20.56, Episode Reward: 14.0 Epsilon: 0.9303965506618875
# E: 18/1000:
# Avg Reward: 20.32, Episode Reward: 16.0 Epsilon: 0.92667496445924
# E: 19/1000:
# Avg Reward: 21.25, Episode Reward: 39.0 Epsilon: 0.922968264601403
# E: 20/1000:
# Avg Reward: 21.14, Episode Reward: 19.0 Epsilon: 0.9192763915429975
# E: 21/1000:
# Avg Reward: 21.00, Episode Reward: 18.0 Epsilon: 0.9155992859768255
# E: 22/1000:
# Avg Reward: 21.09, Episode Reward: 23.0 Epsilon: 0.9119368888329182
# E: 23/1000:
# Avg Reward: 21.00, Episode Reward: 19.0 Epsilon: 0.9082891412775865
# E: 24/1000:
# Avg Reward: 21.00, Episode Reward: 21.0 Epsilon: 0.9046559847124762
# E: 25/1000:
# Avg Reward: 20.69, Episode Reward: 13.0 Epsilon: 0.9010373607736263
# E: 26/1000:
# Avg Reward: 20.44, Episode Reward: 14.0 Epsilon: 0.8974332113305318
# E: 27/1000:
# Avg Reward: 20.11, Episode Reward: 11.0 Epsilon: 0.8938434784852096
# E: 28/1000:
# Avg Reward: 20.66, Episode Reward: 36.0 Epsilon: 0.8902681045712688
# E: 29/1000:
# Avg Reward: 20.50, Episode Reward: 16.0 Epsilon: 0.8867070321529837
# E: 30/1000:
# Avg Reward: 20.16, Episode Reward: 10.0 Epsilon: 0.8831602040243718
# E: 31/1000:
# Avg Reward: 20.12, Episode Reward: 19.0 Epsilon: 0.8796275632082743
# E: 32/1000:
# Avg Reward: 19.88, Episode Reward: 12.0 Epsilon: 0.8761090529554412
# E: 33/1000:
# Avg Reward: 19.65, Episode Reward: 12.0 Epsilon: 0.8726046167436194
# E: 34/1000:
# Avg Reward: 19.60, Episode Reward: 18.0 Epsilon: 0.8691141982766449
# E: 35/1000:
# Avg Reward: 19.36, Episode Reward: 11.0 Epsilon: 0.8656377414835383
# E: 36/1000:
# Avg Reward: 19.46, Episode Reward: 23.0 Epsilon: 0.8621751905176042
# E: 37/1000:
# Avg Reward: 19.32, Episode Reward: 14.0 Epsilon: 0.8587264897555338
# E: 38/1000:
# Avg Reward: 19.13, Episode Reward: 12.0 Epsilon: 0.8552915837965116
# E: 39/1000:
# Avg Reward: 18.98, Episode Reward: 13.0 Epsilon: 0.8518704174613255
# E: 40/1000:
# Avg Reward: 18.95, Episode Reward: 18.0 Epsilon: 0.8484629357914802
# E: 41/1000:
# Avg Reward: 19.02, Episode Reward: 22.0 Epsilon: 0.8450690840483143
# E: 42/1000:
# Avg Reward: 18.95, Episode Reward: 16.0 Epsilon: 0.841688807712121
# E: 43/1000:
# Avg Reward: 19.23, Episode Reward: 31.0 Epsilon: 0.8383220524812725
# E: 44/1000:
# Avg Reward: 19.02, Episode Reward: 10.0 Epsilon: 0.8349687642713474
# E: 45/1000:
# Avg Reward: 18.87, Episode Reward: 12.0 Epsilon: 0.8316288892142619
# E: 46/1000:
# Avg Reward: 19.04, Episode Reward: 27.0 Epsilon: 0.8283023736574049
# E: 47/1000:
# Avg Reward: 18.90, Episode Reward: 12.0 Epsilon: 0.8249891641627752
# E: 48/1000:
# Avg Reward: 19.00, Episode Reward: 24.0 Epsilon: 0.8216892075061242
# E: 49/1000:
# Avg Reward: 18.92, Episode Reward: 15.0 Epsilon: 0.8184024506760996
# E: 50/1000:
# Avg Reward: 18.76, Episode Reward: 11.0 Epsilon: 0.8151288408733952
# E: 51/1000:
# Avg Reward: 18.71, Episode Reward: 16.0 Epsilon: 0.8118683255099016
# E: 52/1000:
# Avg Reward: 18.62, Episode Reward: 14.0 Epsilon: 0.8086208522078621
# E: 53/1000:
# Avg Reward: 18.91, Episode Reward: 34.0 Epsilon: 0.8053863687990306
# E: 54/1000:
# Avg Reward: 18.91, Episode Reward: 19.0 Epsilon: 0.8021648233238344
# E: 55/1000:
# Avg Reward: 19.00, Episode Reward: 24.0 Epsilon: 0.798956164030539
# E: 56/1000:
# Avg Reward: 18.93, Episode Reward: 15.0 Epsilon: 0.7957603393744169
# E: 57/1000:
# Avg Reward: 18.90, Episode Reward: 17.0 Epsilon: 0.7925772980169192
# E: 58/1000:
# Avg Reward: 18.95, Episode Reward: 22.0 Epsilon: 0.7894069888248515
# E: 59/1000:
# Avg Reward: 19.70, Episode Reward: 64.0 Epsilon: 0.7862493608695521
# E: 60/1000:
# Avg Reward: 19.61, Episode Reward: 14.0 Epsilon: 0.7831043634260739
# E: 61/1000:
# Avg Reward: 19.71, Episode Reward: 26.0 Epsilon: 0.7799719459723696
# E: 62/1000:
# Avg Reward: 19.70, Episode Reward: 19.0 Epsilon: 0.7768520581884801
# E: 63/1000:
# Avg Reward: 19.62, Episode Reward: 15.0 Epsilon: 0.7737446499557262
# E: 64/1000:
# Avg Reward: 19.57, Episode Reward: 16.0 Epsilon: 0.7706496713559033
# E: 65/1000:
# Avg Reward: 19.44, Episode Reward: 11.0 Epsilon: 0.7675670726704797
# E: 66/1000:
# Avg Reward: 19.40, Episode Reward: 17.0 Epsilon: 0.7644968043797978
# E: 67/1000:
# Avg Reward: 19.34, Episode Reward: 15.0 Epsilon: 0.7614388171622787
# E: 68/1000:
# Avg Reward: 19.32, Episode Reward: 18.0 Epsilon: 0.7583930618936295
# E: 69/1000:
# Avg Reward: 19.27, Episode Reward: 16.0 Epsilon: 0.755359489646055
# E: 70/1000:
# Avg Reward: 19.17, Episode Reward: 12.0 Epsilon: 0.7523380516874708
# E: 71/1000:
# Avg Reward: 19.17, Episode Reward: 19.0 Epsilon: 0.7493286994807209
# E: 72/1000:
# Avg Reward: 19.14, Episode Reward: 17.0 Epsilon: 0.746331384682798
# E: 73/1000:
# Avg Reward: 19.01, Episode Reward: 10.0 Epsilon: 0.7433460591440668
# E: 74/1000:
# Avg Reward: 19.04, Episode Reward: 21.0 Epsilon: 0.7403726749074906
# E: 75/1000:
# Avg Reward: 19.17, Episode Reward: 29.0 Epsilon: 0.7374111842078607
# E: 76/1000:
# Avg Reward: 19.68, Episode Reward: 58.0 Epsilon: 0.7344615394710292
# E: 77/1000:
# Avg Reward: 19.71, Episode Reward: 22.0 Epsilon: 0.731523693313145
# E: 78/1000:
# Avg Reward: 19.67, Episode Reward: 17.0 Epsilon: 0.7285975985398925
# E: 79/1000:
# Avg Reward: 19.52, Episode Reward: 8.0 Epsilon: 0.725683208145733
# E: 80/1000:
# Avg Reward: 19.60, Episode Reward: 26.0 Epsilon: 0.72278047531315
# E: 81/1000:
# Avg Reward: 19.55, Episode Reward: 15.0 Epsilon: 0.7198893534118974
# E: 82/1000:
# Avg Reward: 19.63, Episode Reward: 26.0 Epsilon: 0.7170097959982499
# E: 83/1000:
# Avg Reward: 19.55, Episode Reward: 13.0 Epsilon: 0.7141417568142568
# E: 84/1000:
# Avg Reward: 19.55, Episode Reward: 20.0 Epsilon: 0.7112851897869998
# E: 85/1000:
# Avg Reward: 19.43, Episode Reward: 9.0 Epsilon: 0.7084400490278518
# E: 86/1000:
# Avg Reward: 19.34, Episode Reward: 12.0 Epsilon: 0.7056062888317405
# E: 87/1000:
# Avg Reward: 19.48, Episode Reward: 31.0 Epsilon: 0.7027838636764135
# E: 88/1000:
# Avg Reward: 19.67, Episode Reward: 37.0 Epsilon: 0.6999727282217079
# E: 89/1000:
# Avg Reward: 19.60, Episode Reward: 13.0 Epsilon: 0.6971728373088211
# E: 90/1000:
# Avg Reward: 19.49, Episode Reward: 10.0 Epsilon: 0.6943841459595858
# E: 91/1000:
# Avg Reward: 19.43, Episode Reward: 14.0 Epsilon: 0.6916066093757474
# E: 92/1000:
# Avg Reward: 19.34, Episode Reward: 11.0 Epsilon: 0.6888401829382443
# E: 93/1000:
# Avg Reward: 19.51, Episode Reward: 35.0 Epsilon: 0.6860848222064914
# E: 94/1000:
# Avg Reward: 19.60, Episode Reward: 28.0 Epsilon: 0.6833404829176654
# E: 95/1000:
# Avg Reward: 19.52, Episode Reward: 12.0 Epsilon: 0.6806071209859947
# E: 96/1000:
# Avg Reward: 19.44, Episode Reward: 12.0 Epsilon: 0.6778846925020507
# E: 97/1000:
# Avg Reward: 19.34, Episode Reward: 9.0 Epsilon: 0.6751731537320426
# E: 98/1000:
# Avg Reward: 19.28, Episode Reward: 14.0 Epsilon: 0.6724724611171143
# E: 99/1000:
# Avg Reward: 19.21, Episode Reward: 12.0 Epsilon: 0.6697825712726458
# E: 100/1000:
# Avg Reward: 18.72, Episode Reward: 10.0 Epsilon: 0.6671034409875553
# E: 101/1000:
# Avg Reward: 18.65, Episode Reward: 10.0 Epsilon: 0.664435027223605
# E: 102/1000:
# Avg Reward: 18.74, Episode Reward: 23.0 Epsilon: 0.6617772871147106
# E: 103/1000:
# Avg Reward: 18.96, Episode Reward: 32.0 Epsilon: 0.6591301779662517
# E: 104/1000:
# Avg Reward: 18.92, Episode Reward: 13.0 Epsilon: 0.6564936572543867
# E: 105/1000:
# Avg Reward: 18.81, Episode Reward: 12.0 Epsilon: 0.6538676826253691
# E: 106/1000:
# Avg Reward: 18.56, Episode Reward: 16.0 Epsilon: 0.6512522118948676
# E: 107/1000:
# Avg Reward: 18.58, Episode Reward: 13.0 Epsilon: 0.6486472030472881
# E: 108/1000:
# Avg Reward: 19.02, Episode Reward: 55.0 Epsilon: 0.646052614235099
# E: 109/1000:
# Avg Reward: 19.08, Episode Reward: 16.0 Epsilon: 0.6434684037781586
# E: 110/1000:
# Avg Reward: 18.81, Episode Reward: 21.0 Epsilon: 0.640894530163046
# E: 111/1000:
# Avg Reward: 19.09, Episode Reward: 40.0 Epsilon: 0.6383309520423938
# E: 112/1000:
# Avg Reward: 19.18, Episode Reward: 18.0 Epsilon: 0.6357776282342242
# E: 113/1000:
# Avg Reward: 19.10, Episode Reward: 22.0 Epsilon: 0.6332345177212874
# E: 114/1000:
# Avg Reward: 19.14, Episode Reward: 19.0 Epsilon: 0.6307015796504022
# E: 115/1000:
# Avg Reward: 19.19, Episode Reward: 14.0 Epsilon: 0.6281787733318006
# E: 116/1000:
# Avg Reward: 19.15, Episode Reward: 16.0 Epsilon: 0.6256660582384734
# E: 117/1000:
# Avg Reward: 19.25, Episode Reward: 24.0 Epsilon: 0.6231633940055196
# E: 118/1000:
# Avg Reward: 19.29, Episode Reward: 20.0 Epsilon: 0.6206707404294974
# E: 119/1000:
# Avg Reward: 20.14, Episode Reward: 124.0 Epsilon: 0.6181880574677795
# E: 120/1000:
# Avg Reward: 20.06, Episode Reward: 11.0 Epsilon: 0.6157153052379084
# E: 121/1000:
# Avg Reward: 20.04, Episode Reward: 16.0 Epsilon: 0.6132524440169568
# E: 122/1000:
# Avg Reward: 19.99, Episode Reward: 18.0 Epsilon: 0.6107994342408889
# E: 123/1000:
# Avg Reward: 19.91, Episode Reward: 11.0 Epsilon: 0.6083562365039253
# E: 124/1000:
# Avg Reward: 19.88, Episode Reward: 18.0 Epsilon: 0.6059228115579096
# E: 125/1000:
# Avg Reward: 19.86, Episode Reward: 11.0 Epsilon: 0.603499120311678
# E: 126/1000:
# Avg Reward: 19.87, Episode Reward: 15.0 Epsilon: 0.6010851238304312
# E: 127/1000:
# Avg Reward: 20.21, Episode Reward: 45.0 Epsilon: 0.5986807833351095
# E: 128/1000:
# Avg Reward: 20.25, Episode Reward: 40.0 Epsilon: 0.5962860602017691
# E: 129/1000:
# Avg Reward: 20.27, Episode Reward: 18.0 Epsilon: 0.5939009159609621
# E: 130/1000:
# Avg Reward: 20.39, Episode Reward: 22.0 Epsilon: 0.5915253122971182
# E: 131/1000:
# Avg Reward: 20.55, Episode Reward: 35.0 Epsilon: 0.5891592110479298
# E: 132/1000:
# Avg Reward: 20.58, Episode Reward: 15.0 Epsilon: 0.586802574203738
# E: 133/1000:
# Avg Reward: 20.81, Episode Reward: 35.0 Epsilon: 0.5844553639069231
# E: 134/1000:
# Avg Reward: 20.72, Episode Reward: 9.0 Epsilon: 0.5821175424512954
# E: 135/1000:
# Avg Reward: 20.70, Episode Reward: 9.0 Epsilon: 0.5797890722814902
# E: 136/1000:
# Avg Reward: 20.60, Episode Reward: 13.0 Epsilon: 0.5774699159923643
# E: 137/1000:
# Avg Reward: 20.57, Episode Reward: 11.0 Epsilon: 0.5751600363283949
# E: 138/1000:
# Avg Reward: 20.90, Episode Reward: 45.0 Epsilon: 0.5728593961830812
# E: 139/1000:
# Avg Reward: 20.91, Episode Reward: 14.0 Epsilon: 0.5705679585983489
# E: 140/1000:
# Avg Reward: 20.92, Episode Reward: 19.0 Epsilon: 0.5682856867639554
# E: 141/1000:
# Avg Reward: 20.83, Episode Reward: 13.0 Epsilon: 0.5660125440168996
# E: 142/1000:
# Avg Reward: 20.98, Episode Reward: 31.0 Epsilon: 0.563748493840832
# E: 143/1000:
# Avg Reward: 21.45, Episode Reward: 78.0 Epsilon: 0.5614934998654687
# E: 144/1000:
# Avg Reward: 21.58, Episode Reward: 23.0 Epsilon: 0.5592475258660068
# E: 145/1000:
# Avg Reward: 21.55, Episode Reward: 9.0 Epsilon: 0.5570105357625428
# E: 146/1000:
# Avg Reward: 21.56, Episode Reward: 28.0 Epsilon: 0.5547824936194926
# E: 147/1000:
# Avg Reward: 21.72, Episode Reward: 28.0 Epsilon: 0.5525633636450147
# E: 148/1000:
# Avg Reward: 21.74, Episode Reward: 26.0 Epsilon: 0.5503531101904346
# E: 149/1000:
# Avg Reward: 21.72, Episode Reward: 13.0 Epsilon: 0.5481516977496729
# E: 150/1000:
# Avg Reward: 21.71, Episode Reward: 10.0 Epsilon: 0.5459590909586742
# E: 151/1000:
# Avg Reward: 21.84, Episode Reward: 29.0 Epsilon: 0.5437752545948396
# E: 152/1000:
# Avg Reward: 21.86, Episode Reward: 16.0 Epsilon: 0.5416001535764602
# E: 153/1000:
# Avg Reward: 21.67, Episode Reward: 15.0 Epsilon: 0.5394337529621543
# E: 154/1000:
# Avg Reward: 21.61, Episode Reward: 13.0 Epsilon: 0.5372760179503058
# E: 155/1000:
# Avg Reward: 22.02, Episode Reward: 65.0 Epsilon: 0.5351269138785045
# E: 156/1000:
# Avg Reward: 21.97, Episode Reward: 10.0 Epsilon: 0.5329864062229905
# E: 157/1000:
# Avg Reward: 22.37, Episode Reward: 57.0 Epsilon: 0.5308544605980986
# E: 158/1000:
# Avg Reward: 23.30, Episode Reward: 115.0 Epsilon: 0.5287310427557061
# E: 159/1000:
# Avg Reward: 22.77, Episode Reward: 11.0 Epsilon: 0.5266161185846833
# E: 160/1000:
# Avg Reward: 22.74, Episode Reward: 11.0 Epsilon: 0.5245096541103446
# E: 161/1000:
# Avg Reward: 22.81, Episode Reward: 33.0 Epsilon: 0.5224116154939031
# E: 162/1000:
# Avg Reward: 23.65, Episode Reward: 103.0 Epsilon: 0.5203219690319275
# E: 163/1000:
# Avg Reward: 23.63, Episode Reward: 13.0 Epsilon: 0.5182406811557998
# E: 164/1000:
# Avg Reward: 23.58, Episode Reward: 11.0 Epsilon: 0.5161677184311766
# E: 165/1000:
# Avg Reward: 23.71, Episode Reward: 24.0 Epsilon: 0.5141030475574518
# E: 166/1000:
# Avg Reward: 23.67, Episode Reward: 13.0 Epsilon: 0.5120466353672221
# E: 167/1000:
# Avg Reward: 23.70, Episode Reward: 18.0 Epsilon: 0.5099984488257532
# E: 168/1000:
# Avg Reward: 24.18, Episode Reward: 66.0 Epsilon: 0.5079584550304501
# E: 169/1000:
# Avg Reward: 24.15, Episode Reward: 13.0 Epsilon: 0.5059266212103283
# E: 170/1000:
# Avg Reward: 24.99, Episode Reward: 96.0 Epsilon: 0.503902914725487
# E: 171/1000:
# Avg Reward: 24.97, Episode Reward: 17.0 Epsilon: 0.501887303066585
# E: 172/1000:
# Avg Reward: 25.22, Episode Reward: 42.0 Epsilon: 0.49987975385431865
# E: 173/1000:
# Avg Reward: 25.27, Episode Reward: 15.0 Epsilon: 0.49788023483890137
# E: 174/1000:
# Avg Reward: 25.19, Episode Reward: 13.0 Epsilon: 0.49588871389954575
# E: 175/1000:
# Avg Reward: 25.07, Episode Reward: 17.0 Epsilon: 0.49390515904394755
# E: 176/1000:
# Avg Reward: 24.61, Episode Reward: 12.0 Epsilon: 0.49192953840777176
# E: 177/1000:
# Avg Reward: 25.14, Episode Reward: 75.0 Epsilon: 0.48996182025414065
# E: 178/1000:
# Avg Reward: 25.49, Episode Reward: 52.0 Epsilon: 0.4880019729731241
# E: 179/1000:
# Avg Reward: 25.62, Episode Reward: 21.0 Epsilon: 0.4860499650812316
# E: 180/1000:
# Avg Reward: 26.18, Episode Reward: 82.0 Epsilon: 0.4841057652209067
# E: 181/1000:
# Avg Reward: 26.80, Episode Reward: 77.0 Epsilon: 0.48216934216002305
# E: 182/1000:
# Avg Reward: 26.65, Episode Reward: 11.0 Epsilon: 0.48024066479138294
# E: 183/1000:
# Avg Reward: 27.20, Episode Reward: 68.0 Epsilon: 0.4783197021322174
# E: 184/1000:
# Avg Reward: 27.17, Episode Reward: 17.0 Epsilon: 0.47640642332368854
# E: 185/1000:
# Avg Reward: 27.47, Episode Reward: 39.0 Epsilon: 0.47450079763039377
# E: 186/1000:
# Avg Reward: 28.11, Episode Reward: 76.0 Epsilon: 0.4726027944398722
# E: 187/1000:
# Avg Reward: 28.00, Episode Reward: 20.0 Epsilon: 0.4707123832621127
# E: 188/1000:
# Avg Reward: 27.78, Episode Reward: 15.0 Epsilon: 0.4688295337290642
# E: 189/1000:
# Avg Reward: 27.80, Episode Reward: 15.0 Epsilon: 0.46695421559414796
# E: 190/1000:
# Avg Reward: 28.30, Episode Reward: 60.0 Epsilon: 0.4650863987317714
# E: 191/1000:
# Avg Reward: 28.36, Episode Reward: 20.0 Epsilon: 0.4632260531368443
# E: 192/1000:
# Avg Reward: 28.49, Episode Reward: 24.0 Epsilon: 0.4613731489242969
# E: 193/1000:
# Avg Reward: 28.28, Episode Reward: 14.0 Epsilon: 0.45952765632859977
# E: 194/1000:
# Avg Reward: 28.75, Episode Reward: 75.0 Epsilon: 0.45768954570328535
# E: 195/1000:
# Avg Reward: 29.02, Episode Reward: 39.0 Epsilon: 0.4558587875204722
# E: 196/1000:
# Avg Reward: 29.67, Episode Reward: 77.0 Epsilon: 0.45403535237039033
# E: 197/1000:
# Avg Reward: 29.80, Episode Reward: 22.0 Epsilon: 0.4522192109609088
# E: 198/1000:
# Avg Reward: 30.12, Episode Reward: 46.0 Epsilon: 0.45041033411706516
# E: 199/1000:
# Avg Reward: 31.05, Episode Reward: 105.0 Epsilon: 0.4486086927805969
# E: 200/1000:
# Avg Reward: 32.11, Episode Reward: 116.0 Epsilon: 0.4468142580094745
# E: 201/1000:
# Avg Reward: 32.25, Episode Reward: 24.0 Epsilon: 0.4450270009774366
# E: 202/1000:
# Avg Reward: 32.71, Episode Reward: 69.0 Epsilon: 0.4432468929735268
# E: 203/1000:
# Avg Reward: 33.24, Episode Reward: 85.0 Epsilon: 0.4414739054016327
# E: 204/1000:
# Avg Reward: 33.69, Episode Reward: 58.0 Epsilon: 0.4397080097800262
# E: 205/1000:
# Avg Reward: 33.72, Episode Reward: 15.0 Epsilon: 0.43794917774090614
# E: 206/1000:
# Avg Reward: 34.74, Episode Reward: 118.0 Epsilon: 0.4361973810299425
# E: 207/1000:
# Avg Reward: 36.01, Episode Reward: 140.0 Epsilon: 0.4344525915058227
# E: 208/1000:
# Avg Reward: 35.62, Episode Reward: 16.0 Epsilon: 0.43271478113979944
# E: 209/1000:
# Avg Reward: 35.99, Episode Reward: 53.0 Epsilon: 0.4309839220152402
# E: 210/1000:
# Avg Reward: 36.65, Episode Reward: 87.0 Epsilon: 0.42925998632717927
# E: 211/1000:
# Avg Reward: 36.91, Episode Reward: 66.0 Epsilon: 0.42754294638187057
# E: 212/1000:
# Avg Reward: 38.17, Episode Reward: 144.0 Epsilon: 0.4258327745963431
# E: 213/1000:
# Avg Reward: 38.50, Episode Reward: 55.0 Epsilon: 0.4241294434979577
# E: 214/1000:
# Avg Reward: 40.54, Episode Reward: 223.0 Epsilon: 0.4224329257239659
# E: 215/1000:
# Avg Reward: 40.50, Episode Reward: 10.0 Epsilon: 0.42074319402107
# E: 216/1000:
# Avg Reward: 41.09, Episode Reward: 75.0 Epsilon: 0.41906022124498576
# E: 217/1000:
# Avg Reward: 41.50, Episode Reward: 65.0 Epsilon: 0.41738398036000585
# E: 218/1000:
# Avg Reward: 41.40, Episode Reward: 10.0 Epsilon: 0.4157144444385658
# E: 219/1000:
# Avg Reward: 41.44, Episode Reward: 128.0 Epsilon: 0.41405158666081154
# E: 220/1000:
# Avg Reward: 41.47, Episode Reward: 14.0 Epsilon: 0.4123953803141683
# E: 221/1000:
# Avg Reward: 42.33, Episode Reward: 102.0 Epsilon: 0.4107457987929116
# E: 222/1000:
# Avg Reward: 42.44, Episode Reward: 29.0 Epsilon: 0.40910281559774
# E: 223/1000:
# Avg Reward: 43.19, Episode Reward: 86.0 Epsilon: 0.40746640433534903
# E: 224/1000:
# Avg Reward: 43.11, Episode Reward: 10.0 Epsilon: 0.4058365387180076
# E: 225/1000:
# Avg Reward: 43.48, Episode Reward: 48.0 Epsilon: 0.4042131925631356
# E: 226/1000:
# Avg Reward: 43.46, Episode Reward: 13.0 Epsilon: 0.40259633979288306
# E: 227/1000:
# Avg Reward: 43.50, Episode Reward: 49.0 Epsilon: 0.40098595443371154
# E: 228/1000:
# Avg Reward: 43.29, Episode Reward: 19.0 Epsilon: 0.3993820106159767
# E: 229/1000:
# Avg Reward: 43.96, Episode Reward: 85.0 Epsilon: 0.3977844825735128
# E: 230/1000:
# Avg Reward: 44.58, Episode Reward: 84.0 Epsilon: 0.39619334464321876
# E: 231/1000:
# Avg Reward: 44.43, Episode Reward: 20.0 Epsilon: 0.3946085712646459
# E: 232/1000:
# Avg Reward: 44.89, Episode Reward: 61.0 Epsilon: 0.3930301369795873
# E: 233/1000:
# Avg Reward: 45.43, Episode Reward: 89.0 Epsilon: 0.39145801643166894
# E: 234/1000:
# Avg Reward: 45.52, Episode Reward: 18.0 Epsilon: 0.38989218436594225
# E: 235/1000:
# Avg Reward: 45.99, Episode Reward: 56.0 Epsilon: 0.3883326156284785
# E: 236/1000:
# Avg Reward: 47.59, Episode Reward: 173.0 Epsilon: 0.38677928516596455
# E: 237/1000:
# Avg Reward: 47.94, Episode Reward: 46.0 Epsilon: 0.3852321680253007
# E: 238/1000:
# Avg Reward: 47.66, Episode Reward: 17.0 Epsilon: 0.3836912393531995
# E: 239/1000:
# Avg Reward: 48.06, Episode Reward: 54.0 Epsilon: 0.3821564743957867
# E: 240/1000:
# Avg Reward: 48.04, Episode Reward: 17.0 Epsilon: 0.3806278484982036
# E: 241/1000:
# Avg Reward: 48.78, Episode Reward: 87.0 Epsilon: 0.37910533710421074
# E: 242/1000:
# Avg Reward: 48.81, Episode Reward: 34.0 Epsilon: 0.3775889157557939
# E: 243/1000:
# Avg Reward: 48.36, Episode Reward: 33.0 Epsilon: 0.37607856009277074
# E: 244/1000:
# Avg Reward: 49.48, Episode Reward: 135.0 Epsilon: 0.3745742458523997
# E: 245/1000:
# Avg Reward: 50.72, Episode Reward: 133.0 Epsilon: 0.3730759488689901
# E: 246/1000:
# Avg Reward: 52.00, Episode Reward: 156.0 Epsilon: 0.37158364507351416
# E: 247/1000:
# Avg Reward: 53.13, Episode Reward: 141.0 Epsilon: 0.3700973104932201
# E: 248/1000:
# Avg Reward: 54.14, Episode Reward: 127.0 Epsilon: 0.36861692125124723
# E: 249/1000:
# Avg Reward: 55.77, Episode Reward: 176.0 Epsilon: 0.36714245356624226
# E: 250/1000:
# Avg Reward: 57.31, Episode Reward: 164.0 Epsilon: 0.3656738837519773
# E: 251/1000:
# Avg Reward: 57.50, Episode Reward: 48.0 Epsilon: 0.3642111882169694
# E: 252/1000:
# Avg Reward: 58.70, Episode Reward: 136.0 Epsilon: 0.3627543434641015
# E: 253/1000:
# Avg Reward: 58.69, Episode Reward: 14.0 Epsilon: 0.3613033260902451
# E: 254/1000:
# Avg Reward: 60.62, Episode Reward: 206.0 Epsilon: 0.35985811278588414
# E: 255/1000:
# Avg Reward: 61.01, Episode Reward: 104.0 Epsilon: 0.3584186803347406
# E: 256/1000:
# Avg Reward: 61.14, Episode Reward: 23.0 Epsilon: 0.35698500561340163
# E: 257/1000:
# Avg Reward: 60.83, Episode Reward: 26.0 Epsilon: 0.355557065590948
# E: 258/1000:
# Avg Reward: 61.46, Episode Reward: 178.0 Epsilon: 0.35413483732858425
# E: 259/1000:
# Avg Reward: 61.88, Episode Reward: 53.0 Epsilon: 0.3527182979792699
# E: 260/1000:
# Avg Reward: 62.68, Episode Reward: 91.0 Epsilon: 0.35130742478735283
# E: 261/1000:
# Avg Reward: 63.08, Episode Reward: 73.0 Epsilon: 0.3499021950882034
# E: 262/1000:
# Avg Reward: 62.54, Episode Reward: 49.0 Epsilon: 0.3485025863078506
# E: 263/1000:
# Avg Reward: 63.54, Episode Reward: 113.0 Epsilon: 0.3471085759626192
# E: 264/1000:
# Avg Reward: 64.28, Episode Reward: 85.0 Epsilon: 0.3457201416587687
# E: 265/1000:
# Avg Reward: 64.63, Episode Reward: 59.0 Epsilon: 0.3443372610921336
# E: 266/1000:
# Avg Reward: 65.46, Episode Reward: 96.0 Epsilon: 0.34295991204776505
# E: 267/1000:
# Avg Reward: 65.94, Episode Reward: 66.0 Epsilon: 0.341588072399574
# E: 268/1000:
# Avg Reward: 66.52, Episode Reward: 124.0 Epsilon: 0.3402217201099757
# E: 269/1000:
# Avg Reward: 69.25, Episode Reward: 286.0 Epsilon: 0.3388608332295358
# E: 270/1000:
# Avg Reward: 70.37, Episode Reward: 208.0 Epsilon: 0.33750538989661766
# E: 271/1000:
# Avg Reward: 71.28, Episode Reward: 108.0 Epsilon: 0.3361553683370312
# E: 272/1000:
# Avg Reward: 72.78, Episode Reward: 192.0 Epsilon: 0.33481074686368306
# E: 273/1000:
# Avg Reward: 74.13, Episode Reward: 150.0 Epsilon: 0.3334715038762283
# E: 274/1000:
# Avg Reward: 75.64, Episode Reward: 164.0 Epsilon: 0.3321376178607234
# E: 275/1000:
# Avg Reward: 76.77, Episode Reward: 130.0 Epsilon: 0.3308090673892805
# E: 276/1000:
# Avg Reward: 76.90, Episode Reward: 25.0 Epsilon: 0.3294858311197234
# E: 277/1000:
# Avg Reward: 76.32, Episode Reward: 17.0 Epsilon: 0.32816788779524453
# E: 278/1000:
# Avg Reward: 77.46, Episode Reward: 166.0 Epsilon: 0.32685521624406355
# E: 279/1000:
# Avg Reward: 78.86, Episode Reward: 161.0 Epsilon: 0.3255477953790873
# E: 280/1000:
# Avg Reward: 78.98, Episode Reward: 94.0 Epsilon: 0.3242456041975709
# E: 281/1000:
# Avg Reward: 79.44, Episode Reward: 123.0 Epsilon: 0.32294862178078065
# E: 282/1000:
# Avg Reward: 80.68, Episode Reward: 135.0 Epsilon: 0.3216568272936575
# E: 283/1000:
# Avg Reward: 81.43, Episode Reward: 143.0 Epsilon: 0.3203701999844829
# E: 284/1000:
# Avg Reward: 82.72, Episode Reward: 146.0 Epsilon: 0.31908871918454496
# E: 285/1000:
# Avg Reward: 83.70, Episode Reward: 137.0 Epsilon: 0.3178123643078068
# E: 286/1000:
# Avg Reward: 84.33, Episode Reward: 139.0 Epsilon: 0.31654111485057557
# E: 287/1000:
# Avg Reward: 85.93, Episode Reward: 180.0 Epsilon: 0.31527495039117326
# E: 288/1000:
# Avg Reward: 87.16, Episode Reward: 138.0 Epsilon: 0.31401385058960857
# E: 289/1000:
# Avg Reward: 87.15, Episode Reward: 14.0 Epsilon: 0.3127577951872501
# E: 290/1000:
# Avg Reward: 88.02, Episode Reward: 147.0 Epsilon: 0.3115067640065011
# E: 291/1000:
# Avg Reward: 89.41, Episode Reward: 159.0 Epsilon: 0.3102607369504751
# E: 292/1000:
# Avg Reward: 91.75, Episode Reward: 258.0 Epsilon: 0.3090196940026732
# E: 293/1000:
# Avg Reward: 93.40, Episode Reward: 179.0 Epsilon: 0.30778361522666253
# E: 294/1000:
# Avg Reward: 92.89, Episode Reward: 24.0 Epsilon: 0.30655248076575586
# E: 295/1000:
# Avg Reward: 93.83, Episode Reward: 133.0 Epsilon: 0.3053262708426928
# E: 296/1000:
# Avg Reward: 94.23, Episode Reward: 117.0 Epsilon: 0.30410496575932205
# E: 297/1000:
# Avg Reward: 94.39, Episode Reward: 38.0 Epsilon: 0.3028885458962848
# E: 298/1000:
# Avg Reward: 95.13, Episode Reward: 120.0 Epsilon: 0.3016769917126996
# E: 299/1000:
# Avg Reward: 95.11, Episode Reward: 103.0 Epsilon: 0.30047028374584883
# E: 300/1000:
# Avg Reward: 95.17, Episode Reward: 122.0 Epsilon: 0.29926840261086546
# E: 301/1000:
# Avg Reward: 96.02, Episode Reward: 109.0 Epsilon: 0.298071329000422
# E: 302/1000:
# Avg Reward: 96.45, Episode Reward: 112.0 Epsilon: 0.2968790436844203
# E: 303/1000:
# Avg Reward: 96.39, Episode Reward: 79.0 Epsilon: 0.29569152750968264
# E: 304/1000:
# Avg Reward: 96.74, Episode Reward: 93.0 Epsilon: 0.2945087613996439
# E: 305/1000:
# Avg Reward: 96.71, Episode Reward: 12.0 Epsilon: 0.2933307263540453
# E: 306/1000:
# Avg Reward: 95.65, Episode Reward: 12.0 Epsilon: 0.2921574034486291
# E: 307/1000:
# Avg Reward: 94.53, Episode Reward: 28.0 Epsilon: 0.2909887738348346
# E: 308/1000:
# Avg Reward: 94.48, Episode Reward: 11.0 Epsilon: 0.2898248187394953
# E: 309/1000:
# Avg Reward: 94.83, Episode Reward: 88.0 Epsilon: 0.2886655194645373
# E: 310/1000:
# Avg Reward: 94.60, Episode Reward: 64.0 Epsilon: 0.28751085738667914
# E: 311/1000:
# Avg Reward: 94.15, Episode Reward: 21.0 Epsilon: 0.2863608139571324
# E: 312/1000:
# Avg Reward: 93.68, Episode Reward: 97.0 Epsilon: 0.28521537070130387
# E: 313/1000:
# Avg Reward: 94.03, Episode Reward: 90.0 Epsilon: 0.28407450921849864
# E: 314/1000:
# Avg Reward: 92.05, Episode Reward: 25.0 Epsilon: 0.28293821118162465
# E: 315/1000:
# Avg Reward: 92.42, Episode Reward: 47.0 Epsilon: 0.28180645833689816
# E: 316/1000:
# Avg Reward: 91.80, Episode Reward: 13.0 Epsilon: 0.2806792325035506
# E: 317/1000:
# Avg Reward: 91.79, Episode Reward: 64.0 Epsilon: 0.2795565155735364
# E: 318/1000:
# Avg Reward: 92.73, Episode Reward: 104.0 Epsilon: 0.2784382895112422
# E: 319/1000:
# Avg Reward: 92.05, Episode Reward: 60.0 Epsilon: 0.27732453635319726
# E: 320/1000:
# Avg Reward: 92.05, Episode Reward: 14.0 Epsilon: 0.2762152382077845
# E: 321/1000:
# Avg Reward: 91.15, Episode Reward: 12.0 Epsilon: 0.27511037725495335
# E: 322/1000:
# Avg Reward: 91.77, Episode Reward: 91.0 Epsilon: 0.2740099357459335
# E: 323/1000:
# Avg Reward: 91.99, Episode Reward: 108.0 Epsilon: 0.2729138960029498
# E: 324/1000:
# Avg Reward: 92.12, Episode Reward: 23.0 Epsilon: 0.271822240418938
# E: 325/1000:
# Avg Reward: 91.86, Episode Reward: 22.0 Epsilon: 0.27073495145726223
# E: 326/1000:
# Avg Reward: 92.48, Episode Reward: 75.0 Epsilon: 0.26965201165143315
# E: 327/1000:
# Avg Reward: 92.96, Episode Reward: 97.0 Epsilon: 0.2685734036048274
# E: 328/1000:
# Avg Reward: 92.93, Episode Reward: 16.0 Epsilon: 0.2674991099904081
# E: 329/1000:
# Avg Reward: 93.03, Episode Reward: 95.0 Epsilon: 0.26642911355044646
# E: 330/1000:
# Avg Reward: 92.34, Episode Reward: 15.0 Epsilon: 0.2653633970962447
# E: 331/1000:
# Avg Reward: 92.62, Episode Reward: 48.0 Epsilon: 0.2643019435078597
# E: 332/1000:
# Avg Reward: 92.71, Episode Reward: 70.0 Epsilon: 0.26324473573382823
# E: 333/1000:
# Avg Reward: 92.14, Episode Reward: 32.0 Epsilon: 0.2621917567908929
# E: 334/1000:
# Avg Reward: 92.95, Episode Reward: 99.0 Epsilon: 0.26114298976372935
# E: 335/1000:
# Avg Reward: 92.54, Episode Reward: 15.0 Epsilon: 0.2600984178046744
# E: 336/1000:
# Avg Reward: 91.78, Episode Reward: 97.0 Epsilon: 0.2590580241334557
# E: 337/1000:
# Avg Reward: 91.87, Episode Reward: 55.0 Epsilon: 0.2580217920369219
# E: 338/1000:
# Avg Reward: 91.87, Episode Reward: 17.0 Epsilon: 0.2569897048687742
# E: 339/1000:
# Avg Reward: 92.39, Episode Reward: 106.0 Epsilon: 0.2559617460492991
# E: 340/1000:
# Avg Reward: 93.18, Episode Reward: 96.0 Epsilon: 0.2549378990651019
# E: 341/1000:
# Avg Reward: 93.27, Episode Reward: 96.0 Epsilon: 0.2539181474688415
# E: 342/1000:
# Avg Reward: 93.02, Episode Reward: 9.0 Epsilon: 0.2529024748789661
# E: 343/1000:
# Avg Reward: 92.84, Episode Reward: 15.0 Epsilon: 0.25189086497945024
# E: 344/1000:
# Avg Reward: 92.42, Episode Reward: 93.0 Epsilon: 0.2508833015195324
# E: 345/1000:
# Avg Reward: 91.42, Episode Reward: 33.0 Epsilon: 0.2498797683134543
# E: 346/1000:
# Avg Reward: 90.04, Episode Reward: 18.0 Epsilon: 0.24888024924020047
# E: 347/1000:
# Avg Reward: 89.69, Episode Reward: 106.0 Epsilon: 0.24788472824323968
# E: 348/1000:
# Avg Reward: 88.58, Episode Reward: 16.0 Epsilon: 0.24689318933026672
# E: 349/1000:
# Avg Reward: 86.96, Episode Reward: 14.0 Epsilon: 0.24590561657294566
# E: 350/1000:
# Avg Reward: 86.29, Episode Reward: 97.0 Epsilon: 0.24492199410665388
# E: 351/1000:
# Avg Reward: 87.29, Episode Reward: 148.0 Epsilon: 0.24394230613022727
# E: 352/1000:
# Avg Reward: 87.05, Episode Reward: 112.0 Epsilon: 0.24296653690570635
# E: 353/1000:
# Avg Reward: 88.10, Episode Reward: 119.0 Epsilon: 0.24199467075808354
# E: 354/1000:
# Avg Reward: 86.24, Episode Reward: 20.0 Epsilon: 0.2410266920750512
# E: 355/1000:
# Avg Reward: 85.36, Episode Reward: 16.0 Epsilon: 0.240062585306751
# E: 356/1000:
# Avg Reward: 85.93, Episode Reward: 80.0 Epsilon: 0.239102334965524
# E: 357/1000:
# Avg Reward: 86.31, Episode Reward: 64.0 Epsilon: 0.2381459256256619
# E: 358/1000:
# Avg Reward: 84.72, Episode Reward: 19.0 Epsilon: 0.23719334192315925
# E: 359/1000:
# Avg Reward: 85.26, Episode Reward: 107.0 Epsilon: 0.2362445685554666
# E: 360/1000:
# Avg Reward: 85.40, Episode Reward: 105.0 Epsilon: 0.23529959028124472
# E: 361/1000:
# Avg Reward: 85.43, Episode Reward: 76.0 Epsilon: 0.23435839192011976
# E: 362/1000:
# Avg Reward: 85.95, Episode Reward: 101.0 Epsilon: 0.23342095835243928
# E: 363/1000:
# Avg Reward: 84.99, Episode Reward: 17.0 Epsilon: 0.23248727451902954
# E: 364/1000:
# Avg Reward: 84.25, Episode Reward: 11.0 Epsilon: 0.23155732542095342
# E: 365/1000:
# Avg Reward: 83.93, Episode Reward: 27.0 Epsilon: 0.2306310961192696
# E: 366/1000:
# Avg Reward: 84.80, Episode Reward: 183.0 Epsilon: 0.22970857173479253
# E: 367/1000:
# Avg Reward: 85.04, Episode Reward: 90.0 Epsilon: 0.22878973744785336
# E: 368/1000:
# Avg Reward: 84.40, Episode Reward: 60.0 Epsilon: 0.22787457849806195
# E: 369/1000:
# Avg Reward: 81.90, Episode Reward: 36.0 Epsilon: 0.2269630801840697
# E: 370/1000:
# Avg Reward: 80.89, Episode Reward: 107.0 Epsilon: 0.2260552278633334
# E: 371/1000:
# Avg Reward: 80.11, Episode Reward: 30.0 Epsilon: 0.22515100695188006
# E: 372/1000:
# Avg Reward: 78.38, Episode Reward: 19.0 Epsilon: 0.22425040292407253
# E: 373/1000:
# Avg Reward: 77.34, Episode Reward: 46.0 Epsilon: 0.22335340131237624
# E: 374/1000:
# Avg Reward: 77.31, Episode Reward: 161.0 Epsilon: 0.22245998770712674
# E: 375/1000:
# Avg Reward: 77.46, Episode Reward: 145.0 Epsilon: 0.22157014775629824
# E: 376/1000:
# Avg Reward: 78.39, Episode Reward: 118.0 Epsilon: 0.22068386716527305
# E: 377/1000:
# Avg Reward: 78.36, Episode Reward: 14.0 Epsilon: 0.21980113169661195
# E: 378/1000:
# Avg Reward: 77.87, Episode Reward: 117.0 Epsilon: 0.2189219271698255
# E: 379/1000:
# Avg Reward: 76.37, Episode Reward: 11.0 Epsilon: 0.2180462394611462
# E: 380/1000:
# Avg Reward: 76.95, Episode Reward: 152.0 Epsilon: 0.21717405450330163
# E: 381/1000:
# Avg Reward: 77.09, Episode Reward: 137.0 Epsilon: 0.2163053582852884
# E: 382/1000:
# Avg Reward: 76.69, Episode Reward: 95.0 Epsilon: 0.21544013685214725
# E: 383/1000:
# Avg Reward: 75.38, Episode Reward: 12.0 Epsilon: 0.21457837630473867
# E: 384/1000:
# Avg Reward: 74.07, Episode Reward: 15.0 Epsilon: 0.21372006279951972
# E: 385/1000:
# Avg Reward: 73.67, Episode Reward: 97.0 Epsilon: 0.21286518254832162
# E: 386/1000:
# Avg Reward: 72.40, Episode Reward: 12.0 Epsilon: 0.21201372181812833
# E: 387/1000:
# Avg Reward: 70.72, Episode Reward: 12.0 Epsilon: 0.2111656669308558
# E: 388/1000:
# Avg Reward: 70.07, Episode Reward: 73.0 Epsilon: 0.21032100426313238
# E: 389/1000:
# Avg Reward: 70.67, Episode Reward: 74.0 Epsilon: 0.20947972024607986
# E: 390/1000:
# Avg Reward: 69.30, Episode Reward: 10.0 Epsilon: 0.20864180136509555
# E: 391/1000:
# Avg Reward: 68.82, Episode Reward: 111.0 Epsilon: 0.20780723415963517
# E: 392/1000:
# Avg Reward: 66.35, Episode Reward: 11.0 Epsilon: 0.20697600522299664
# E: 393/1000:
# Avg Reward: 64.74, Episode Reward: 18.0 Epsilon: 0.20614810120210464
# E: 394/1000:
# Avg Reward: 64.85, Episode Reward: 35.0 Epsilon: 0.20532350879729622
# E: 395/1000:
# Avg Reward: 63.99, Episode Reward: 47.0 Epsilon: 0.20450221476210703
# E: 396/1000:
# Avg Reward: 63.76, Episode Reward: 94.0 Epsilon: 0.2036842059030586
# E: 397/1000:
# Avg Reward: 63.62, Episode Reward: 24.0 Epsilon: 0.20286946907944636
# E: 398/1000:
# Avg Reward: 62.59, Episode Reward: 17.0 Epsilon: 0.2020579912031286
# E: 399/1000:
# Avg Reward: 61.73, Episode Reward: 17.0 Epsilon: 0.20124975923831606
# E: 400/1000:
# Avg Reward: 60.70, Episode Reward: 19.0 Epsilon: 0.2004447602013628
# E: 401/1000:
# Avg Reward: 60.77, Episode Reward: 116.0 Epsilon: 0.19964298116055734
# E: 402/1000:
# Avg Reward: 60.64, Episode Reward: 99.0 Epsilon: 0.19884440923591512
# E: 403/1000:
# Avg Reward: 60.99, Episode Reward: 114.0 Epsilon: 0.19804903159897147
# E: 404/1000:
# Avg Reward: 60.20, Episode Reward: 14.0 Epsilon: 0.19725683547257558
# E: 405/1000:
# Avg Reward: 60.20, Episode Reward: 12.0 Epsilon: 0.1964678081306853
# E: 406/1000:
# Avg Reward: 60.29, Episode Reward: 21.0 Epsilon: 0.19568193689816255
# E: 407/1000:
# Avg Reward: 60.96, Episode Reward: 95.0 Epsilon: 0.1948992091505699
# E: 408/1000:
# Avg Reward: 62.35, Episode Reward: 150.0 Epsilon: 0.19411961231396763
# E: 409/1000:
# Avg Reward: 62.67, Episode Reward: 120.0 Epsilon: 0.19334313386471175
# E: 410/1000:
# Avg Reward: 62.23, Episode Reward: 20.0 Epsilon: 0.1925697613292529
# E: 411/1000:
# Avg Reward: 62.82, Episode Reward: 80.0 Epsilon: 0.1917994822839359
# E: 412/1000:
# Avg Reward: 63.10, Episode Reward: 125.0 Epsilon: 0.19103228435480016
# E: 413/1000:
# Avg Reward: 62.40, Episode Reward: 20.0 Epsilon: 0.19026815521738097
# E: 414/1000:
# Avg Reward: 63.45, Episode Reward: 130.0 Epsilon: 0.18950708259651144
# E: 415/1000:
# Avg Reward: 63.10, Episode Reward: 12.0 Epsilon: 0.1887490542661254
# E: 416/1000:
# Avg Reward: 64.23, Episode Reward: 126.0 Epsilon: 0.18799405804906089
# E: 417/1000:
# Avg Reward: 64.64, Episode Reward: 105.0 Epsilon: 0.18724208181686464
# E: 418/1000:
# Avg Reward: 64.65, Episode Reward: 105.0 Epsilon: 0.18649311348959718
# E: 419/1000:
# Avg Reward: 64.38, Episode Reward: 33.0 Epsilon: 0.1857471410356388
# E: 420/1000:
# Avg Reward: 64.97, Episode Reward: 73.0 Epsilon: 0.18500415247149624
# E: 421/1000:
# Avg Reward: 64.97, Episode Reward: 12.0 Epsilon: 0.18426413586161025
# E: 422/1000:
# Avg Reward: 65.15, Episode Reward: 109.0 Epsilon: 0.1835270793181638
# E: 423/1000:
# Avg Reward: 64.94, Episode Reward: 87.0 Epsilon: 0.18279297100089115
# E: 424/1000:
# Avg Reward: 64.82, Episode Reward: 11.0 Epsilon: 0.18206179911688758
# E: 425/1000:
# Avg Reward: 65.26, Episode Reward: 66.0 Epsilon: 0.18133355192042003
# E: 426/1000:
# Avg Reward: 64.63, Episode Reward: 12.0 Epsilon: 0.18060821771273836
# E: 427/1000:
# Avg Reward: 65.13, Episode Reward: 147.0 Epsilon: 0.17988578484188741
# E: 428/1000:
# Avg Reward: 65.07, Episode Reward: 10.0 Epsilon: 0.17916624170251985
# E: 429/1000:
# Avg Reward: 64.27, Episode Reward: 15.0 Epsilon: 0.17844957673570977
# E: 430/1000:
# Avg Reward: 64.57, Episode Reward: 45.0 Epsilon: 0.17773577842876692
# E: 431/1000:
# Avg Reward: 64.30, Episode Reward: 21.0 Epsilon: 0.17702483531505186
# E: 432/1000:
# Avg Reward: 64.11, Episode Reward: 51.0 Epsilon: 0.17631673597379166
# E: 433/1000:
# Avg Reward: 64.89, Episode Reward: 110.0 Epsilon: 0.1756114690298965
# E: 434/1000:
# Avg Reward: 65.67, Episode Reward: 177.0 Epsilon: 0.1749090231537769
# E: 435/1000:
# Avg Reward: 67.21, Episode Reward: 169.0 Epsilon: 0.1742093870611618
# E: 436/1000:
# Avg Reward: 68.30, Episode Reward: 206.0 Epsilon: 0.17351254951291714
# E: 437/1000:
# Avg Reward: 68.92, Episode Reward: 117.0 Epsilon: 0.17281849931486548
# E: 438/1000:
# Avg Reward: 69.47, Episode Reward: 72.0 Epsilon: 0.17212722531760602
# E: 439/1000:
# Avg Reward: 70.08, Episode Reward: 167.0 Epsilon: 0.1714387164163356
# E: 440/1000:
# Avg Reward: 72.74, Episode Reward: 362.0 Epsilon: 0.17075296155067024
# E: 441/1000:
# Avg Reward: 73.52, Episode Reward: 174.0 Epsilon: 0.17006994970446757
# E: 442/1000:
# Avg Reward: 78.36, Episode Reward: 493.0 Epsilon: 0.1693896699056497
# E: 443/1000:
# Avg Reward: 80.92, Episode Reward: 271.0 Epsilon: 0.16871211122602708
# E: 444/1000:
# Avg Reward: 81.28, Episode Reward: 129.0 Epsilon: 0.16803726278112296
# E: 445/1000:
# Avg Reward: 84.22, Episode Reward: 327.0 Epsilon: 0.16736511372999846
# E: 446/1000:
# Avg Reward: 85.92, Episode Reward: 188.0 Epsilon: 0.16669565327507846
# E: 447/1000:
# Avg Reward: 86.82, Episode Reward: 196.0 Epsilon: 0.16602887066197813
# E: 448/1000:
# Avg Reward: 87.09, Episode Reward: 43.0 Epsilon: 0.16536475517933022
# E: 449/1000:
# Avg Reward: 87.62, Episode Reward: 67.0 Epsilon: 0.1647032961586129
# E: 450/1000:
# Avg Reward: 89.09, Episode Reward: 244.0 Epsilon: 0.16404448297397844
# E: 451/1000:
# Avg Reward: 90.27, Episode Reward: 266.0 Epsilon: 0.16338830504208254
# E: 452/1000:
# Avg Reward: 92.54, Episode Reward: 339.0 Epsilon: 0.16273475182191421
# E: 453/1000:
# Avg Reward: 93.90, Episode Reward: 255.0 Epsilon: 0.16208381281462655
# E: 454/1000:
# Avg Reward: 95.81, Episode Reward: 211.0 Epsilon: 0.16143547756336804
# E: 455/1000:
# Avg Reward: 98.09, Episode Reward: 244.0 Epsilon: 0.16078973565311458
# E: 456/1000:
# Avg Reward: 98.42, Episode Reward: 113.0 Epsilon: 0.16014657671050211
# E: 457/1000:
# Avg Reward: 99.18, Episode Reward: 140.0 Epsilon: 0.1595059904036601
# E: 458/1000:
# Avg Reward: 102.77, Episode Reward: 378.0 Epsilon: 0.15886796644204546
# E: 459/1000:
# Avg Reward: 103.42, Episode Reward: 172.0 Epsilon: 0.15823249457627728
# E: 460/1000:
# Avg Reward: 104.39, Episode Reward: 202.0 Epsilon: 0.15759956459797217
# E: 461/1000:
# Avg Reward: 105.22, Episode Reward: 159.0 Epsilon: 0.15696916633958027
# E: 462/1000:
# Avg Reward: 106.09, Episode Reward: 188.0 Epsilon: 0.15634128967422195
# E: 463/1000:
# Avg Reward: 107.18, Episode Reward: 126.0 Epsilon: 0.15571592451552507
# E: 464/1000:
# Avg Reward: 108.36, Episode Reward: 129.0 Epsilon: 0.15509306081746296
# E: 465/1000:
# Avg Reward: 109.33, Episode Reward: 124.0 Epsilon: 0.1544726885741931
# E: 466/1000:
# Avg Reward: 109.22, Episode Reward: 172.0 Epsilon: 0.15385479781989633
# E: 467/1000:
# Avg Reward: 109.83, Episode Reward: 151.0 Epsilon: 0.15323937862861675
# E: 468/1000:
# Avg Reward: 110.73, Episode Reward: 150.0 Epsilon: 0.1526264211141023
# E: 469/1000:
# Avg Reward: 111.71, Episode Reward: 134.0 Epsilon: 0.15201591542964588
# E: 470/1000:
# Avg Reward: 111.48, Episode Reward: 84.0 Epsilon: 0.1514078517679273
# E: 471/1000:
# Avg Reward: 111.34, Episode Reward: 16.0 Epsilon: 0.15080222036085558
# E: 472/1000:
# Avg Reward: 112.28, Episode Reward: 113.0 Epsilon: 0.15019901147941217
# E: 473/1000:
# Avg Reward: 112.98, Episode Reward: 116.0 Epsilon: 0.14959821543349452
# E: 474/1000:
# Avg Reward: 114.57, Episode Reward: 320.0 Epsilon: 0.14899982257176056
# E: 475/1000:
# Avg Reward: 114.35, Episode Reward: 123.0 Epsilon: 0.14840382328147353
# E: 476/1000:
# Avg Reward: 114.28, Episode Reward: 111.0 Epsilon: 0.14781020798834762
# E: 477/1000:
# Avg Reward: 115.36, Episode Reward: 122.0 Epsilon: 0.14721896715639424
# E: 478/1000:
# Avg Reward: 115.08, Episode Reward: 89.0 Epsilon: 0.14663009128776866
# E: 479/1000:
# Avg Reward: 116.53, Episode Reward: 156.0 Epsilon: 0.14604357092261758
# E: 480/1000:
# Avg Reward: 116.56, Episode Reward: 155.0 Epsilon: 0.1454593966389271
# E: 481/1000:
# Avg Reward: 116.53, Episode Reward: 134.0 Epsilon: 0.14487755905237137
# E: 482/1000:
# Avg Reward: 116.37, Episode Reward: 79.0 Epsilon: 0.1442980488161619
# E: 483/1000:
# Avg Reward: 117.89, Episode Reward: 164.0 Epsilon: 0.14372085662089726
# E: 484/1000:
# Avg Reward: 119.14, Episode Reward: 140.0 Epsilon: 0.14314597319441366
# E: 485/1000:
# Avg Reward: 119.31, Episode Reward: 114.0 Epsilon: 0.14257338930163602
# E: 486/1000:
# Avg Reward: 120.31, Episode Reward: 112.0 Epsilon: 0.14200309574442946
# E: 487/1000:
# Avg Reward: 121.90, Episode Reward: 171.0 Epsilon: 0.14143508336145175
# E: 488/1000:
# Avg Reward: 122.75, Episode Reward: 158.0 Epsilon: 0.14086934302800594
# E: 489/1000:
# Avg Reward: 124.24, Episode Reward: 223.0 Epsilon: 0.14030586565589392
# E: 490/1000:
# Avg Reward: 126.15, Episode Reward: 201.0 Epsilon: 0.13974464219327035
# E: 491/1000:
# Avg Reward: 126.94, Episode Reward: 190.0 Epsilon: 0.13918566362449727
# E: 492/1000:
# Avg Reward: 128.19, Episode Reward: 136.0 Epsilon: 0.1386289209699993
# E: 493/1000:
# Avg Reward: 130.85, Episode Reward: 284.0 Epsilon: 0.1380744052861193
# E: 494/1000:
# Avg Reward: 132.17, Episode Reward: 167.0 Epsilon: 0.13752210766497483
# E: 495/1000:
# Avg Reward: 131.93, Episode Reward: 23.0 Epsilon: 0.13697201923431493
# E: 496/1000:
# Avg Reward: 132.26, Episode Reward: 127.0 Epsilon: 0.13642413115737767
# E: 497/1000:
# Avg Reward: 133.53, Episode Reward: 151.0 Epsilon: 0.13587843463274815
# E: 498/1000:
# Avg Reward: 135.08, Episode Reward: 172.0 Epsilon: 0.13533492089421717
# E: 499/1000:
# Avg Reward: 136.38, Episode Reward: 147.0 Epsilon: 0.1347935812106403
# E: 500/1000:
# Avg Reward: 137.93, Episode Reward: 174.0 Epsilon: 0.13425440688579773
# E: 501/1000:
# Avg Reward: 138.31, Episode Reward: 154.0 Epsilon: 0.13371738925825455
# E: 502/1000:
# Avg Reward: 138.52, Episode Reward: 120.0 Epsilon: 0.13318251970122152
# E: 503/1000:
# Avg Reward: 140.03, Episode Reward: 265.0 Epsilon: 0.13264978962241664
# E: 504/1000:
# Avg Reward: 141.51, Episode Reward: 162.0 Epsilon: 0.13211919046392698
# E: 505/1000:
# Avg Reward: 142.55, Episode Reward: 116.0 Epsilon: 0.13159071370207126
# E: 506/1000:
# Avg Reward: 143.57, Episode Reward: 123.0 Epsilon: 0.13106435084726298
# E: 507/1000:
# Avg Reward: 143.86, Episode Reward: 124.0 Epsilon: 0.13054009344387393
# E: 508/1000:
# Avg Reward: 143.56, Episode Reward: 120.0 Epsilon: 0.13001793307009843
# E: 509/1000:
# Avg Reward: 143.48, Episode Reward: 112.0 Epsilon: 0.12949786133781804
# E: 510/1000:
# Avg Reward: 145.24, Episode Reward: 196.0 Epsilon: 0.12897986989246676
# E: 511/1000:
# Avg Reward: 145.23, Episode Reward: 79.0 Epsilon: 0.1284639504128969
# E: 512/1000:
# Avg Reward: 146.98, Episode Reward: 300.0 Epsilon: 0.12795009461124532
# E: 513/1000:
# Avg Reward: 148.20, Episode Reward: 142.0 Epsilon: 0.12743829423280034
# E: 514/1000:
# Avg Reward: 146.99, Episode Reward: 9.0 Epsilon: 0.12692854105586915
# E: 515/1000:
# Avg Reward: 148.15, Episode Reward: 128.0 Epsilon: 0.12642082689164566
# E: 516/1000:
# Avg Reward: 148.19, Episode Reward: 130.0 Epsilon: 0.12591514358407907
# E: 517/1000:
# Avg Reward: 148.86, Episode Reward: 172.0 Epsilon: 0.12541148300974275
# E: 518/1000:
# Avg Reward: 147.96, Episode Reward: 15.0 Epsilon: 0.12490983707770378
# E: 519/1000:
# Avg Reward: 148.82, Episode Reward: 119.0 Epsilon: 0.12441019772939296
# E: 520/1000:
# Avg Reward: 148.25, Episode Reward: 16.0 Epsilon: 0.12391255693847539
# E: 521/1000:
# Avg Reward: 148.53, Episode Reward: 40.0 Epsilon: 0.12341690671072149
# E: 522/1000:
# Avg Reward: 149.45, Episode Reward: 201.0 Epsilon: 0.1229232390838786
# E: 523/1000:
# Avg Reward: 150.14, Episode Reward: 156.0 Epsilon: 0.12243154612754309
# E: 524/1000:
# Avg Reward: 151.20, Episode Reward: 117.0 Epsilon: 0.12194181994303292
# E: 525/1000:
# Avg Reward: 152.10, Episode Reward: 156.0 Epsilon: 0.12145405266326079
# E: 526/1000:
# Avg Reward: 153.22, Episode Reward: 124.0 Epsilon: 0.12096823645260775
# E: 527/1000:
# Avg Reward: 152.97, Episode Reward: 122.0 Epsilon: 0.12048436350679732
# E: 528/1000:
# Avg Reward: 154.05, Episode Reward: 118.0 Epsilon: 0.12000242605277013
# E: 529/1000:
# Avg Reward: 155.51, Episode Reward: 161.0 Epsilon: 0.11952241634855905
# E: 530/1000:
# Avg Reward: 156.38, Episode Reward: 132.0 Epsilon: 0.11904432668316481
# E: 531/1000:
# Avg Reward: 158.41, Episode Reward: 224.0 Epsilon: 0.11856814937643215
# E: 532/1000:
# Avg Reward: 159.61, Episode Reward: 171.0 Epsilon: 0.11809387677892642
# E: 533/1000:
# Avg Reward: 160.09, Episode Reward: 158.0 Epsilon: 0.11762150127181072
# E: 534/1000:
# Avg Reward: 159.93, Episode Reward: 161.0 Epsilon: 0.11715101526672347
# E: 535/1000:
# Avg Reward: 159.94, Episode Reward: 170.0 Epsilon: 0.11668241120565657
# E: 536/1000:
# Avg Reward: 159.42, Episode Reward: 154.0 Epsilon: 0.11621568156083395
# E: 537/1000:
# Avg Reward: 159.32, Episode Reward: 107.0 Epsilon: 0.11575081883459061
# E: 538/1000:
# Avg Reward: 160.13, Episode Reward: 153.0 Epsilon: 0.11528781555925224
# E: 539/1000:
# Avg Reward: 160.47, Episode Reward: 201.0 Epsilon: 0.11482666429701524
# E: 540/1000:
# Avg Reward: 157.36, Episode Reward: 51.0 Epsilon: 0.11436735763982718
# E: 541/1000:
# Avg Reward: 157.24, Episode Reward: 162.0 Epsilon: 0.11390988820926787
# E: 542/1000:
# Avg Reward: 153.59, Episode Reward: 128.0 Epsilon: 0.11345424865643079
# E: 543/1000:
# Avg Reward: 152.23, Episode Reward: 135.0 Epsilon: 0.11300043166180507
# E: 544/1000:
# Avg Reward: 152.53, Episode Reward: 159.0 Epsilon: 0.11254842993515785
# E: 545/1000:
# Avg Reward: 149.57, Episode Reward: 31.0 Epsilon: 0.11209823621541722
# E: 546/1000:
# Avg Reward: 149.05, Episode Reward: 136.0 Epsilon: 0.11164984327055555
# E: 547/1000:
# Avg Reward: 148.82, Episode Reward: 173.0 Epsilon: 0.11120324389747333
# E: 548/1000:
# Avg Reward: 150.20, Episode Reward: 181.0 Epsilon: 0.11075843092188344
# E: 549/1000:
# Avg Reward: 151.05, Episode Reward: 152.0 Epsilon: 0.1103153971981959
# E: 550/1000:
# Avg Reward: 148.78, Episode Reward: 17.0 Epsilon: 0.10987413560940311
# E: 551/1000:
# Avg Reward: 147.18, Episode Reward: 106.0 Epsilon: 0.1094346390669655
# E: 552/1000:
# Avg Reward: 145.40, Episode Reward: 161.0 Epsilon: 0.10899690051069764
# E: 553/1000:
# Avg Reward: 144.71, Episode Reward: 186.0 Epsilon: 0.10856091290865486
# E: 554/1000:
# Avg Reward: 144.06, Episode Reward: 146.0 Epsilon: 0.10812666925702023
# E: 555/1000:
# Avg Reward: 142.94, Episode Reward: 132.0 Epsilon: 0.10769416257999215
# E: 556/1000:
# Avg Reward: 142.03, Episode Reward: 22.0 Epsilon: 0.10726338592967218
# E: 557/1000:
# Avg Reward: 141.70, Episode Reward: 107.0 Epsilon: 0.10683433238595348
# E: 558/1000:
# Avg Reward: 140.54, Episode Reward: 262.0 Epsilon: 0.10640699505640967
# E: 559/1000:
# Avg Reward: 140.47, Episode Reward: 165.0 Epsilon: 0.10598136707618404
# E: 560/1000:
# Avg Reward: 139.52, Episode Reward: 107.0 Epsilon: 0.1055574416078793
# E: 561/1000:
# Avg Reward: 139.67, Episode Reward: 174.0 Epsilon: 0.10513521184144779
# E: 562/1000:
# Avg Reward: 139.62, Episode Reward: 183.0 Epsilon: 0.10471467099408201
# E: 563/1000:
# Avg Reward: 140.23, Episode Reward: 187.0 Epsilon: 0.10429581231010568
# E: 564/1000:
# Avg Reward: 141.54, Episode Reward: 260.0 Epsilon: 0.10387862906086526
# E: 565/1000:
# Avg Reward: 143.14, Episode Reward: 284.0 Epsilon: 0.1034631145446218
# E: 566/1000:
# Avg Reward: 143.49, Episode Reward: 207.0 Epsilon: 0.10304926208644331
# E: 567/1000:
# Avg Reward: 143.87, Episode Reward: 189.0 Epsilon: 0.10263706503809754
# E: 568/1000:
# Avg Reward: 143.79, Episode Reward: 142.0 Epsilon: 0.10222651677794514
# E: 569/1000:
# Avg Reward: 144.51, Episode Reward: 206.0 Epsilon: 0.10181761071083337
# E: 570/1000:
# Avg Reward: 145.09, Episode Reward: 142.0 Epsilon: 0.10141034026799003
# E: 571/1000:
# Avg Reward: 147.56, Episode Reward: 263.0 Epsilon: 0.10100469890691807
# E: 572/1000:
# Avg Reward: 148.01, Episode Reward: 158.0 Epsilon: 0.1006006801112904
# E: 573/1000:
# Avg Reward: 148.28, Episode Reward: 143.0 Epsilon: 0.10019827739084525
# E: 574/1000:
# Avg Reward: 145.22, Episode Reward: 14.0 Epsilon: 0.09979748428128186
# E: 575/1000:
# Avg Reward: 145.53, Episode Reward: 154.0 Epsilon: 0.09939829434415674
# E: 576/1000:
# Avg Reward: 146.05, Episode Reward: 163.0 Epsilon: 0.09900070116678011
# E: 577/1000:
# Avg Reward: 146.04, Episode Reward: 121.0 Epsilon: 0.098604698362113
# E: 578/1000:
# Avg Reward: 147.52, Episode Reward: 237.0 Epsilon: 0.09821027956866454
# E: 579/1000:
# Avg Reward: 147.83, Episode Reward: 187.0 Epsilon: 0.09781743845038988
# E: 580/1000:
# ...
# Avg Reward: 254.86, Episode Reward: 58.0 Epsilon: 0.03844520123314909
# E: 813/1000:
# Avg Reward: 251.21, Episode Reward: 135.0 Epsilon: 0.03829142042821649
# E: 814/1000:
# Avg Reward: 248.11, Episode Reward: 16.0 Epsilon: 0.038138254746503626
# E: 815/1000:
# Avg Reward: 246.70, Episode Reward: 94.0 Epsilon: 0.03798570172751761
# E: 816/1000:
# Avg Reward: 241.82, Episode Reward: 12.0 Epsilon: 0.037833758920607544
# E: 817/1000:
# Avg Reward: 237.89, Episode Reward: 107.0 Epsilon: 0.03768242388492511
# E: 818/1000:
# Avg Reward: 235.58, Episode Reward: 256.0 Epsilon: 0.037531694189385414
# E: 819/1000:
# Avg Reward: 232.30, Episode Reward: 12.0 Epsilon: 0.037381567412627874
# E: 820/1000:
# Avg Reward: 227.40, Episode Reward: 10.0 Epsilon: 0.03723204114297736
# E: 821/1000:
# Avg Reward: 228.52, Episode Reward: 151.0 Epsilon: 0.03708311297840545
# E: 822/1000:
# Avg Reward: 227.63, Episode Reward: 151.0 Epsilon: 0.03693478052649183
# E: 823/1000:
# Avg Reward: 222.95, Episode Reward: 30.0 Epsilon: 0.036787041404385865
# E: 824/1000:
# Avg Reward: 221.49, Episode Reward: 11.0 Epsilon: 0.036639893238768324
# E: 825/1000:
# Avg Reward: 220.46, Episode Reward: 40.0 Epsilon: 0.03649333366581325
# E: 826/1000:
# Avg Reward: 219.34, Episode Reward: 34.0 Epsilon: 0.03634736033114999
# E: 827/1000:
# Avg Reward: 218.23, Episode Reward: 12.0 Epsilon: 0.036201970889825394
# E: 828/1000:
# Avg Reward: 216.62, Episode Reward: 12.0 Epsilon: 0.036057163006266095
# E: 829/1000:
# Avg Reward: 215.25, Episode Reward: 11.0 Epsilon: 0.03591293435424103
# E: 830/1000:
# Avg Reward: 214.16, Episode Reward: 40.0 Epsilon: 0.03576928261682407
# E: 831/1000:
# Avg Reward: 212.25, Episode Reward: 12.0 Epsilon: 0.035626205486356775
# E: 832/1000:
# Avg Reward: 210.93, Episode Reward: 12.0 Epsilon: 0.035483700664411345
# E: 833/1000:
# Avg Reward: 209.14, Episode Reward: 28.0 Epsilon: 0.0353417658617537
# E: 834/1000:
# Avg Reward: 207.25, Episode Reward: 9.0 Epsilon: 0.035200398798306685
# E: 835/1000:
# Avg Reward: 204.50, Episode Reward: 11.0 Epsilon: 0.03505959720311346
# E: 836/1000:
# Avg Reward: 200.97, Episode Reward: 29.0 Epsilon: 0.034919358814301006
# E: 837/1000:
# Avg Reward: 199.45, Episode Reward: 10.0 Epsilon: 0.0347796813790438
# E: 838/1000:
# Avg Reward: 197.97, Episode Reward: 12.0 Epsilon: 0.03464056265352763
# E: 839/1000:
# Avg Reward: 196.82, Episode Reward: 50.0 Epsilon: 0.03450200040291352
# E: 840/1000:
# Avg Reward: 195.43, Episode Reward: 11.0 Epsilon: 0.03436399240130186
# E: 841/1000:
# Avg Reward: 196.03, Episode Reward: 230.0 Epsilon: 0.03422653643169665
# E: 842/1000:
# Avg Reward: 197.03, Episode Reward: 259.0 Epsilon: 0.03408963028596987
# E: 843/1000:
# Avg Reward: 197.47, Episode Reward: 286.0 Epsilon: 0.03395327176482599
# E: 844/1000:
# Avg Reward: 200.87, Episode Reward: 500.0 Epsilon: 0.033817458677766685
# E: 845/1000:
# Avg Reward: 202.06, Episode Reward: 500.0 Epsilon: 0.03368218884305562
# E: 846/1000:
# Avg Reward: 205.66, Episode Reward: 500.0 Epsilon: 0.033547460087683396
# E: 847/1000:
# Avg Reward: 209.26, Episode Reward: 500.0 Epsilon: 0.03341327024733266
# E: 848/1000:
# Avg Reward: 212.93, Episode Reward: 500.0 Epsilon: 0.03327961716634333
# E: 849/1000:
# Avg Reward: 216.62, Episode Reward: 500.0 Epsilon: 0.03314649869767796
# E: 850/1000:
# Avg Reward: 220.26, Episode Reward: 500.0 Epsilon: 0.03301391270288725
# E: 851/1000:
# Avg Reward: 223.97, Episode Reward: 500.0 Epsilon: 0.0328818570520757
# E: 852/1000:
# Avg Reward: 227.23, Episode Reward: 463.0 Epsilon: 0.0327503296238674
# E: 853/1000:
# Avg Reward: 227.13, Episode Reward: 236.0 Epsilon: 0.032619328305371925
# E: 854/1000:
# Avg Reward: 225.11, Episode Reward: 21.0 Epsilon: 0.03248885099215044
# E: 855/1000:
# Avg Reward: 221.66, Episode Reward: 34.0 Epsilon: 0.032358895588181835
# E: 856/1000:
# Avg Reward: 223.85, Episode Reward: 369.0 Epsilon: 0.03222946000582911
# E: 857/1000:
# Avg Reward: 220.71, Episode Reward: 13.0 Epsilon: 0.032100542165805795
# E: 858/1000:
# Avg Reward: 219.16, Episode Reward: 32.0 Epsilon: 0.031972139997142573
# E: 859/1000:
# Avg Reward: 218.17, Episode Reward: 54.0 Epsilon: 0.031844251437154004
# E: 860/1000:
# Avg Reward: 217.07, Episode Reward: 48.0 Epsilon: 0.03171687443140539
# E: 861/1000:
# Avg Reward: 214.83, Episode Reward: 86.0 Epsilon: 0.03159000693367977
# E: 862/1000:
# Avg Reward: 212.63, Episode Reward: 10.0 Epsilon: 0.03146364690594505
# E: 863/1000:
# Avg Reward: 207.95, Episode Reward: 32.0 Epsilon: 0.031337792318321275
# E: 864/1000:
# Avg Reward: 206.56, Episode Reward: 42.0 Epsilon: 0.03121244114904799
# E: 865/1000:
# Avg Reward: 205.28, Episode Reward: 11.0 Epsilon: 0.031087591384451798
# E: 866/1000:
# Avg Reward: 203.82, Episode Reward: 32.0 Epsilon: 0.03096324101891399
# E: 867/1000:
# Avg Reward: 206.81, Episode Reward: 500.0 Epsilon: 0.030839388054838334
# E: 868/1000:
# Avg Reward: 207.99, Episode Reward: 500.0 Epsilon: 0.03071603050261898
# E: 869/1000:
# Avg Reward: 211.38, Episode Reward: 500.0 Epsilon: 0.030593166380608505
# E: 870/1000:
# Avg Reward: 215.96, Episode Reward: 500.0 Epsilon: 0.03047079371508607
# E: 871/1000:
# Avg Reward: 219.49, Episode Reward: 500.0 Epsilon: 0.030348910540225725
# E: 872/1000:
# Avg Reward: 222.55, Episode Reward: 500.0 Epsilon: 0.03022751489806482
# E: 873/1000:
# Avg Reward: 227.13, Episode Reward: 500.0 Epsilon: 0.03010660483847256
# E: 874/1000:
# Avg Reward: 228.96, Episode Reward: 500.0 Epsilon: 0.02998617841911867
# E: 875/1000:
# Avg Reward: 228.98, Episode Reward: 500.0 Epsilon: 0.029866233705442193
# E: 876/1000:
# Avg Reward: 232.34, Episode Reward: 500.0 Epsilon: 0.029746768770620425
# E: 877/1000:
# Avg Reward: 236.04, Episode Reward: 500.0 Epsilon: 0.029627781695537942
# E: 878/1000:
# Avg Reward: 240.58, Episode Reward: 500.0 Epsilon: 0.02950927056875579
# E: 879/1000:
# Avg Reward: 243.71, Episode Reward: 500.0 Epsilon: 0.029391233486480765
# E: 880/1000:
# Avg Reward: 243.71, Episode Reward: 500.0 Epsilon: 0.02927366855253484
# E: 881/1000:
# Avg Reward: 243.71, Episode Reward: 500.0 Epsilon: 0.0291565738783247
# E: 882/1000:
# Avg Reward: 245.33, Episode Reward: 500.0 Epsilon: 0.0290399475828114
# E: 883/1000:
# Avg Reward: 248.24, Episode Reward: 404.0 Epsilon: 0.028923787792480154
# E: 884/1000:
# Avg Reward: 243.74, Episode Reward: 50.0 Epsilon: 0.028808092641310235
# E: 885/1000:
# Avg Reward: 239.56, Episode Reward: 82.0 Epsilon: 0.028692860270744993
# E: 886/1000:
# Avg Reward: 235.31, Episode Reward: 75.0 Epsilon: 0.028578088829662014
# E: 887/1000:
# Avg Reward: 233.43, Episode Reward: 312.0 Epsilon: 0.028463776474343366
# E: 888/1000:
# Avg Reward: 228.74, Episode Reward: 31.0 Epsilon: 0.028349921368445993
# E: 889/1000:
# Avg Reward: 224.06, Episode Reward: 32.0 Epsilon: 0.028236521682972207
# E: 890/1000:
# Avg Reward: 219.19, Episode Reward: 13.0 Epsilon: 0.02812357559624032
# E: 891/1000:
# Avg Reward: 214.53, Episode Reward: 34.0 Epsilon: 0.028011081293855357
# E: 892/1000:
# Avg Reward: 213.28, Episode Reward: 101.0 Epsilon: 0.027899036968679937
# E: 893/1000:
# Avg Reward: 209.02, Episode Reward: 39.0 Epsilon: 0.027787440820805216
# E: 894/1000:
# Avg Reward: 204.51, Episode Reward: 13.0 Epsilon: 0.027676291057521996
# E: 895/1000:
# Avg Reward: 199.85, Episode Reward: 34.0 Epsilon: 0.02756558589329191
# E: 896/1000:
# Avg Reward: 195.01, Episode Reward: 16.0 Epsilon: 0.027455323549718743
# E: 897/1000:
# Avg Reward: 190.12, Episode Reward: 11.0 Epsilon: 0.027345502255519866
# E: 898/1000:
# Avg Reward: 187.15, Episode Reward: 203.0 Epsilon: 0.027236120246497787
# E: 899/1000:
# Avg Reward: 182.25, Episode Reward: 10.0 Epsilon: 0.027127175765511796
# E: 900/1000:
# Avg Reward: 177.38, Episode Reward: 13.0 Epsilon: 0.02701866706244975
# E: 901/1000:
# Avg Reward: 177.10, Episode Reward: 274.0 Epsilon: 0.02691059239419995
# E: 902/1000:
# Avg Reward: 180.15, Episode Reward: 320.0 Epsilon: 0.02680295002462315
# E: 903/1000:
# Avg Reward: 185.05, Episode Reward: 500.0 Epsilon: 0.026695738224524656
# E: 904/1000:
# Avg Reward: 184.32, Episode Reward: 12.0 Epsilon: 0.026588955271626556
# E: 905/1000:
# Avg Reward: 185.88, Episode Reward: 194.0 Epsilon: 0.02648259945054005
# E: 906/1000:
# Avg Reward: 187.55, Episode Reward: 178.0 Epsilon: 0.02637666905273789
# E: 907/1000:
# Avg Reward: 187.13, Episode Reward: 21.0 Epsilon: 0.02627116237652694
# E: 908/1000:
# Avg Reward: 187.57, Episode Reward: 55.0 Epsilon: 0.026166077727020832
# E: 909/1000:
# Avg Reward: 187.68, Episode Reward: 25.0 Epsilon: 0.026061413416112747
# E: 910/1000:
# Avg Reward: 190.96, Episode Reward: 397.0 Epsilon: 0.025957167762448295
# E: 911/1000:
# Avg Reward: 190.95, Episode Reward: 12.0 Epsilon: 0.025853339091398503
# E: 912/1000:
# Avg Reward: 190.63, Episode Reward: 26.0 Epsilon: 0.02574992573503291
# E: 913/1000:
# Avg Reward: 189.38, Episode Reward: 10.0 Epsilon: 0.025646926032092777
# E: 914/1000:
# Avg Reward: 189.34, Episode Reward: 12.0 Epsilon: 0.025544338327964405
# E: 915/1000:
# Avg Reward: 193.40, Episode Reward: 500.0 Epsilon: 0.025442160974652548
# E: 916/1000:
# Avg Reward: 198.28, Episode Reward: 500.0 Epsilon: 0.025340392330753938
# E: 917/1000:
# Avg Reward: 199.72, Episode Reward: 251.0 Epsilon: 0.02523903076143092
# E: 918/1000:
# Avg Reward: 202.16, Episode Reward: 500.0 Epsilon: 0.0251380746383852
# E: 919/1000:
# Avg Reward: 205.12, Episode Reward: 308.0 Epsilon: 0.02503752233983166
# E: 920/1000:
# Avg Reward: 207.49, Episode Reward: 247.0 Epsilon: 0.024937372250472333
# E: 921/1000:
# Avg Reward: 207.12, Episode Reward: 114.0 Epsilon: 0.024837622761470442
# E: 922/1000:
# Avg Reward: 207.93, Episode Reward: 232.0 Epsilon: 0.02473827227042456
# E: 923/1000:
# Avg Reward: 208.39, Episode Reward: 76.0 Epsilon: 0.02463931918134286
# E: 924/1000:
# Avg Reward: 213.20, Episode Reward: 492.0 Epsilon: 0.02454076190461749
# E: 925/1000:
# Avg Reward: 215.28, Episode Reward: 248.0 Epsilon: 0.02444259885699902
# E: 926/1000:
# Avg Reward: 215.46, Episode Reward: 52.0 Epsilon: 0.024344828461571023
# E: 927/1000:
# Avg Reward: 218.49, Episode Reward: 315.0 Epsilon: 0.02424744914772474
# E: 928/1000:
# Avg Reward: 220.07, Episode Reward: 170.0 Epsilon: 0.02415045935113384
# E: 929/1000:
# Avg Reward: 221.53, Episode Reward: 157.0 Epsilon: 0.024053857513729304
# E: 930/1000:
# Avg Reward: 222.39, Episode Reward: 126.0 Epsilon: 0.023957642083674385
# E: 931/1000:
# Avg Reward: 224.48, Episode Reward: 221.0 Epsilon: 0.023861811515339688
# E: 932/1000:
# Avg Reward: 225.98, Episode Reward: 162.0 Epsilon: 0.02376636426927833
# E: 933/1000:
# Avg Reward: 230.21, Episode Reward: 451.0 Epsilon: 0.023671298812201216
# E: 934/1000:
# Avg Reward: 235.12, Episode Reward: 500.0 Epsilon: 0.023576613616952413
# E: 935/1000:
# Avg Reward: 236.57, Episode Reward: 156.0 Epsilon: 0.023482307162484603
# E: 936/1000:
# Avg Reward: 237.56, Episode Reward: 128.0 Epsilon: 0.023388377933834664
# E: 937/1000:
# Avg Reward: 240.04, Episode Reward: 258.0 Epsilon: 0.023294824422099326
# E: 938/1000:
# Avg Reward: 244.92, Episode Reward: 500.0 Epsilon: 0.02320164512441093
# E: 939/1000:
# Avg Reward: 249.42, Episode Reward: 500.0 Epsilon: 0.023108838543913286
# E: 940/1000:
# Avg Reward: 254.31, Episode Reward: 500.0 Epsilon: 0.023016403189737633
# E: 941/1000:
# Avg Reward: 257.01, Episode Reward: 500.0 Epsilon: 0.022924337576978683
# E: 942/1000:
# Avg Reward: 259.42, Episode Reward: 500.0 Epsilon: 0.022832640226670767
# E: 943/1000:
# Avg Reward: 257.96, Episode Reward: 140.0 Epsilon: 0.022741309665764084
# E: 944/1000:
# Avg Reward: 254.82, Episode Reward: 186.0 Epsilon: 0.022650344427101027
# E: 945/1000:
# Avg Reward: 250.00, Episode Reward: 18.0 Epsilon: 0.022559743049392622
# E: 946/1000:
# Avg Reward: 245.68, Episode Reward: 68.0 Epsilon: 0.02246950407719505
# E: 947/1000:
# Avg Reward: 243.56, Episode Reward: 288.0 Epsilon: 0.02237962606088627
# E: 948/1000:
# Avg Reward: 238.98, Episode Reward: 42.0 Epsilon: 0.022290107556642725
# E: 949/1000:
# Avg Reward: 234.99, Episode Reward: 101.0 Epsilon: 0.022200947126416154
# E: 950/1000:
# Avg Reward: 230.33, Episode Reward: 34.0 Epsilon: 0.02211214333791049
# E: 951/1000:
# Avg Reward: 226.32, Episode Reward: 99.0 Epsilon: 0.022023694764558847
# E: 952/1000:
# Avg Reward: 222.52, Episode Reward: 83.0 Epsilon: 0.021935599985500612
# E: 953/1000:
# Avg Reward: 220.83, Episode Reward: 67.0 Epsilon: 0.02184785758555861
# E: 954/1000:
# Avg Reward: 221.03, Episode Reward: 41.0 Epsilon: 0.021760466155216377
# E: 955/1000:
# Avg Reward: 221.83, Episode Reward: 114.0 Epsilon: 0.021673424290595513
# E: 956/1000:
# Avg Reward: 221.14, Episode Reward: 300.0 Epsilon: 0.02158673059343313
# E: 957/1000:
# Avg Reward: 221.33, Episode Reward: 32.0 Epsilon: 0.021500383671059397
# E: 958/1000:
# Avg Reward: 221.11, Episode Reward: 10.0 Epsilon: 0.02141438213637516
# E: 959/1000:
# Avg Reward: 220.99, Episode Reward: 42.0 Epsilon: 0.02132872460782966
# E: 960/1000:
# Avg Reward: 225.51, Episode Reward: 500.0 Epsilon: 0.02124340970939834
# E: 961/1000:
# Avg Reward: 225.16, Episode Reward: 51.0 Epsilon: 0.021158436070560747
# E: 962/1000:
# Avg Reward: 230.06, Episode Reward: 500.0 Epsilon: 0.021073802326278503
# E: 963/1000:
# Avg Reward: 232.10, Episode Reward: 236.0 Epsilon: 0.02098950711697339
# E: 964/1000:
# Avg Reward: 233.35, Episode Reward: 167.0 Epsilon: 0.020905549088505497
# E: 965/1000:
# Avg Reward: 236.82, Episode Reward: 358.0 Epsilon: 0.020821926892151475
# E: 966/1000:
# Avg Reward: 236.95, Episode Reward: 45.0 Epsilon: 0.02073863918458287
# E: 967/1000:
# Avg Reward: 232.05, Episode Reward: 10.0 Epsilon: 0.020655684627844537
# E: 968/1000:
# Avg Reward: 227.18, Episode Reward: 13.0 Epsilon: 0.02057306188933316
# E: 969/1000:
# Avg Reward: 227.18, Episode Reward: 500.0 Epsilon: 0.020490769641775826
# E: 970/1000:
# Avg Reward: 222.57, Episode Reward: 39.0 Epsilon: 0.02040880656320872
# E: 971/1000:
# Avg Reward: 222.57, Episode Reward: 500.0 Epsilon: 0.020327171336955885
# E: 972/1000:
# Avg Reward: 222.57, Episode Reward: 500.0 Epsilon: 0.020245862651608063
# E: 973/1000:
# Avg Reward: 222.57, Episode Reward: 500.0 Epsilon: 0.02016487920100163
# E: 974/1000:
# Avg Reward: 222.57, Episode Reward: 500.0 Epsilon: 0.020084219684197623
# E: 975/1000:
# Avg Reward: 222.57, Episode Reward: 500.0 Epsilon: 0.02000388280546083
# E: 976/1000:
# Avg Reward: 222.57, Episode Reward: 500.0 Epsilon: 0.019923867274238987
# E: 977/1000:
# Avg Reward: 222.57, Episode Reward: 500.0 Epsilon: 0.01984417180514203
# E: 978/1000:
# Avg Reward: 222.57, Episode Reward: 500.0 Epsilon: 0.019764795117921462
# E: 979/1000:
# Avg Reward: 222.57, Episode Reward: 500.0 Epsilon: 0.019685735937449777
# E: 980/1000:
# Avg Reward: 222.57, Episode Reward: 500.0 Epsilon: 0.019606992993699977
# E: 981/1000:
# Avg Reward: 222.57, Episode Reward: 500.0 Epsilon: 0.019528565021725175
# E: 982/1000:
# Avg Reward: 222.57, Episode Reward: 500.0 Epsilon: 0.019450450761638274
# E: 983/1000:
# Avg Reward: 223.53, Episode Reward: 500.0 Epsilon: 0.019372648958591723
# E: 984/1000:
# Avg Reward: 228.03, Episode Reward: 500.0 Epsilon: 0.019295158362757355
# E: 985/1000:
# Avg Reward: 232.21, Episode Reward: 500.0 Epsilon: 0.019217977729306324
# E: 986/1000:
# Avg Reward: 236.46, Episode Reward: 500.0 Epsilon: 0.019141105818389098
# E: 987/1000:
# Avg Reward: 238.34, Episode Reward: 500.0 Epsilon: 0.019064541395115542
# E: 988/1000:
# Avg Reward: 243.03, Episode Reward: 500.0 Epsilon: 0.01898828322953508
# E: 989/1000:
# Avg Reward: 247.71, Episode Reward: 500.0 Epsilon: 0.018912330096616938
# E: 990/1000:
# Avg Reward: 252.58, Episode Reward: 500.0 Epsilon: 0.01883668077623047
# E: 991/1000:
# Avg Reward: 257.24, Episode Reward: 500.0 Epsilon: 0.018761334053125547
# E: 992/1000:
# Avg Reward: 261.23, Episode Reward: 500.0 Epsilon: 0.018686288716913045
# E: 993/1000:
# Avg Reward: 265.84, Episode Reward: 500.0 Epsilon: 0.018611543562045394
# E: 994/1000:
# Avg Reward: 270.71, Episode Reward: 500.0 Epsilon: 0.018537097387797213
# E: 995/1000:
# Avg Reward: 275.37, Episode Reward: 500.0 Epsilon: 0.018462948998246024
# E: 996/1000:
# Avg Reward: 280.21, Episode Reward: 500.0 Epsilon: 0.01838909720225304
# E: 997/1000:
# Avg Reward: 284.61, Episode Reward: 451.0 Epsilon: 0.01831554081344403
# E: 998/1000:
# Avg Reward: 287.58, Episode Reward: 500.0 Epsilon: 0.018242278650190253
# E: 999/1000:
# Avg Reward: 292.48, Episode Reward: 500.0 Epsilon: 0.01816930953558949

# %%
import matplotlib.pyplot as plt


# Create a list of iteration numbers
iterations = list(range(len(running_reward_graph)))

# Create the plot
plt.plot(iterations, running_reward_graph)

# Set the title and labels
plt.title("Reward Values Over Training Iterations")
plt.xlabel("Iteration")
plt.ylabel("Reward")

# Show the plot
plt.show()

# %% [markdown]
# Evaluate the performance of the agent on 100 episodes on the environment and print out the average testing performance. Alternatively you can make sure the code above terminates with 100 episodes where there is no exploration at all (epsilon=0).

# %%
from tqdm import tqdm


def evaluate(num_episodes):
    running_reward = 0
    max_steps_per_episode = 1000
    for episode in tqdm(range(num_episodes)):
        state = env.reset()[0]
        for timestep in range(1, max_steps_per_episode):
            action = select_action(state, 0)                        #returns a scalar
            state_next, reward, done, truncated, _ = env.step(action)
            running_reward += reward

            state = state_next

            if done or truncated: break
    return running_reward/num_episodes

avg_reward_of_trained_model = evaluate(100)
# Out:
# 100%|██████████| 100/100 [01:34<00:00,  1.06it/s]

# %%
avg_reward_of_trained_model
# Out:
# 421.86
